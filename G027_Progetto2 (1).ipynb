# %% [markdown]
# # **Estrazione e preparazione dei dati dalla cartella** `gruppo_0` (training)

# %% [markdown]
# ### Estrazione da zip, lettura dei file audio, salvataggio dati di training e labels, **normalizzazione tra 0 e 1**

# %%
# Librerie e funzioni per estrazione dei file e trattamento di file audio
import zipfile
import os

from scipy.io import wavfile
from scipy.io.wavfile import write

import numpy as np

# %%
# Funzione per estrazione file audio -------------------------------------------------------------------------------------------------------------------------
def wav_labels_file_reading (zip, extract_dir):
    with zipfile.ZipFile(zip, 'r') as zip_ref:
      zip_ref.extractall(extract_dir)                                    # estrazione dei file in una nuova cartella
    extracted_files = os.listdir(extract_dir)                            # funzione che estrapola le informazioni dai file contenuti nella cartella
    paths = []                                                           # lista delle stringhe con i nomi dei file
    audio_data = []                                                      # lista dei dati audio
    label = []                                                           # lista delle label
    for i in range(len(labels_df)):                                      # ciclo per i file contenuti nella cartella
        file_path = os.path.join('gruppo_0',labels_df['new_name'][i])    # raccolta nome del file
        label.append(labels_df['original'][i])
        paths.append(file_path)
        sr, data = wavfile.read(file_path)                               # lettura audio e sample rate da file
        audio_data.append((data.astype(float)))                          # creazione array dei dati audio del singolo file
    return  label, sr, paths, audio_data

# Normalizzazione dati audio sul valore massimo presente in tutto il dataset di audio ------------------------------------------------------------------------
def Normalize(data):
  concatenated_data = np.concatenate(data)
  min_val = np.min(concatenated_data)
  max_val = np.max(concatenated_data)
  return [(x - min_val) / (max_val - min_val) for x in data]

# %%
# Ricerca percorsi e creazione cartella dei file estratti
labels_path = '/content/labels_0.csv'

zip_path = '/content/gruppo_0.zip'

training_directory = 'gruppo_0'
os.makedirs(training_directory, exist_ok=True)

# %%
# Lettura file csv delle labels ed estrazione della labels
import pandas as pd

labels_df = pd.read_csv(labels_path)
for i in range(len(labels_df)): labels_df['original'][i] = labels_df['original'][i][14]
#display(labels_df)

# %%
# LETTURA DATI DA ZIP

labels, sample_rate, paths, audio_data = wav_labels_file_reading(zip_path,training_directory) # chiamata della funzione per la cartella

labels = [int(item) for item in labels]
n_paths = len(audio_data)

# NORMALIZZAZIONE

audio_norm = Normalize(audio_data)

# STAMPA CAMPIONI

for i in range(len(paths)): print(f"{i+1:6d})  {paths[i]}  / label: {labels[i]} / freq: {sample_rate/1000}kHz / dim.: {len(audio_norm[i])} / data: {audio_norm[i]}")
print(f'\nnumero di file contenuti nel dataset: {n_paths}')
# Out:
#      1)  gruppo_0/Jimj64DZx57eogD.wav  / label: 0 / freq: 16.0kHz / dim.: 64000 / data: [0.60710008 0.60329264 0.60711796 ... 0.44711581 0.44506015 0.45480221]
#      2)  gruppo_0/r1qtwd8yOYKlyCq.wav  / label: 0 / freq: 16.0kHz / dim.: 64000 / data: [0.55016713 0.55064977 0.53985306 ... 0.52624993 0.51797365 0.5246054 ]
#      3)  gruppo_0/yr7tYZ0BFodO7NW.wav  / label: 0 / freq: 16.0kHz / dim.: 64000 / data: [0.53651038 0.53263143 0.53009313 ... 0.53710026 0.55029226 0.54235561]
#      4)  gruppo_0/zSgJJrovxQE0aiT.wav  / label: 0 / freq: 16.0kHz / dim.: 64000 / data: [0.54514416 0.54800422 0.53329282 ... 0.53146953 0.54196235 0.54317788]
#      5)  gruppo_0/5ASwAmP6I6inLbK.wav  / label: 0 / freq: 16.0kHz / dim.: 64000 / data: [0.55227642 0.55197254 0.55283056 ... 0.44615055 0.45029762 0.45474858]
#      6)  gruppo_0/kHqPEQut9Eb3f4t.wav  / label: 0 / freq: 16.0kHz / dim.: 64000 / data: [0.60209499 0.54973813 0.3920419  ... 0.52725095 0.51590011 0.54605581]
#      7)  gruppo_0/uFLhJaQINvVSw3x.wav  / label: 0 / freq: 16.0kHz / dim.: 64000 / data: [0.6186118  0.6304274  0.62899737 ... 0.39214915 0.34965947 0.33889852]
#      8)  gruppo_0/OWwHVlluOu0dxia.wav  / label: 0 / freq: 16.0kHz / dim.: 64000 / data: [0.53661763 0.53763652 0.53833366 ... 0.53070089 0.53316769 0.5362065 ]
#      9)  gruppo_0/UqTs5SqzC2OJQDk.wav  / label: 0 / freq: 16.0kHz / dim.: 64000 / data: [0.52612481 0.52221011 0.51699051 ... 0.52101246 0.50685519 0.49659475]
#     10)  gruppo_0/0ANVO5LfU1PEhaP.wav  / label: 0 / freq: 16.0kHz / dim.: 64000 / data: [0.5366355  0.53238117 0.52378314 ... 0.54442915 0.54051445 0.53429383]
#     11)  gruppo_0/Xv1LVSwoJTSjIdZ.wav  / label: 0 / freq: 16.0kHz / dim.: 64000 / data: [0.55735302 0.58647194 0.59160217 ... 0.62309851 0.6170924  0.58766959]
#     12)  gruppo_0/Y5EJFm8MIjUu5pp.wav  / label: 0 / freq: 16.0kHz / dim.: 64000 / data: [0.43011637 0.42704181 0.43215416 ... 0.48542266 0.46397226 0.45723326]
#     13)  gruppo_0/AxpxmEEb7Bex2IR.wav  / label: 0 / freq: 16.0kHz / dim.: 64000 / data: [0.49852528 0.47827253 0.49305543 ... 0.45812702 0.46931698 0.48881898]
#     14)  gruppo_0/BaM0EJJy6kkJaRV.wav  / label: 0 / freq: 16.0kHz / dim.: 64000 / data: [0.49459271 0.48116833 0.4622026  ... 0.57873192 0.58479166 0.58799135]
#     15)  gruppo_0/9D3CFm3OfToAjQS.wav  / label: 0 / freq: 16.0kHz / dim.: 64000 / data: [0.53860179 0.53688576 0.52801959 ... 0.53316769 0.53109415 0.5325778 ]
#     16)  gruppo_0/bWYC7wDCMCxnx1j.wav  / label: 0 / freq: 16.0kHz / dim.: 64000 / data: [0.44818833 0.4475627  0.44897485 ... 0.4847434  0.48722807 0.4888011 ]
#     17)  gruppo_0/EewA0SBB2LQrXZE.wav  / label: 0 / freq: 16.0kHz / dim.: 64000 / data: [0.48100745 0.49711313 0.49487872 ... 0.41622723 0.44641868 0.46497328]
#     18)  gruppo_0/ox2fr00JiE7iSer.wav  / label: 0 / freq: 16.0kHz / dim.: 64000 / data: [0.5391738  0.54941637 0.54214111 ... 0.57565737 0.53981731 0.46513415]
#     19)  gruppo_0/Sf2R7d2rUaGB1mZ.wav  / label: 0 / freq: 16.0kHz / dim.: 64000 / data: [0.54487603 0.54612731 0.54271312 ... 0.59848417 0.59437284 0.59683964]
#     20)  gruppo_0/g6v99PfMaumU8yh.wav  / label: 0 / freq: 16.0kHz / dim.: 64000 / data: [0.50229698 0.49230467 0.4888726  ... 0.48983787 0.5019216  0.489963  ]
#     21)  gruppo_0/lWqnZZcxPY3A4TM.wav  / label: 0 / freq: 16.0kHz / dim.: 64000 / data: [0.53429383 0.53443684 0.53447259 ... 0.53125503 0.53272081 0.53486585]
#     22)  gruppo_0/l1rLF1PWNQVrosx.wav  / label: 0 / freq: 16.0kHz / dim.: 64000 / data: [0.61342795 0.60735034 0.61641313 ... 0.36127844 0.35940153 0.36858946]
#     23)  gruppo_0/EGVGcFs2F7k6JIH.wav  / label: 0 / freq: 16.0kHz / dim.: 64000 / data: [0.54135459 0.53729689 0.53440109 ... 0.51529235 0.53248843 0.52394401]
#     24)  gruppo_0/kMY8XZu6beqXz25.wav  / label: 0 / freq: 16.0kHz / dim.: 64000 / data: [0.52877036 0.53164828 0.53865542 ... 0.53958493 0.53988882 0.54514416]
#     25)  gruppo_0/5Kwv4rzPFL8XXhF.wav  / label: 0 / freq: 16.0kHz / dim.: 64000 / data: [0.54998838 0.5511324  0.55293781 ... 0.51761615 0.51720501 0.51716926]
#     26)  gruppo_0/OttzRH6EUvRFS7z.wav  / label: 0 / freq: 16.0kHz / dim.: 64000 / data: [0.56166098 0.5405502  0.51348694 ... 0.5030835  0.50878573 0.48345638]
#     27)  gruppo_0/I0fEZIgTGZVGjrs.wav  / label: 0 / freq: 16.0kHz / dim.: 64000 / data: [0.4320469  0.41611998 0.41956992 ... 0.61110416 0.52701857 0.45347943]
#     28)  gruppo_0/r2TqHzQqTyV0qXt.wav  / label: 0 / freq: 16.0kHz / dim.: 64000 / data: [0.5325778  0.53297106 0.53347157 ... 0.53781528 0.53452621 0.53077239]
#     29)  gruppo_0/nNU1bBKztt2VpVs.wav  / label: 0 / freq: 16.0kHz / dim.: 64000 / data: [0.58350464 0.59149491 0.59274619 ... 0.55277693 0.55468959 0.55308081]
#     30)  gruppo_0/FcQgda25UMiwmjQ.wav  / label: 0 / freq: 16.0kHz / dim.: 64000 / data: [0.5482366  0.54450065 0.5469317  ... 0.52333625 0.54457215 0.5548326 ]
#     31)  gruppo_0/RNGUXcyi739ZdjX.wav  / label: 0 / freq: 16.0kHz / dim.: 64000 / data: [0.52889548 0.54929124 0.53095115 ... 0.46851259 0.61975582 0.59498061]
#     32)  gruppo_0/pCkKfoXFUJC2X2h.wav  / label: 0 / freq: 16.0kHz / dim.: 64000 / data: [0.54401802 0.55334894 0.56328763 ... 0.52621418 0.52685769 0.53255993]
#     33)  gruppo_0/KbOmtRBhkqVzjkq.wav  / label: 0 / freq: 16.0kHz / dim.: 64000 / data: [0.52131634 0.52397977 0.52412277 ... 0.53681426 0.53676063 0.53870904]
#     34)  gruppo_0/bUbdhTy0lbKVF5C.wav  / label: 0 / freq: 16.0kHz / dim.: 64000 / data: [0.53963856 0.53802978 0.5363495  ... 0.55865792 0.5760685  0.58631107]
#     35)  gruppo_0/POl6O0CHqFj7pN7.wav  / label: 0 / freq: 16.0kHz / dim.: 64000 / data: [0.53291743 0.52894911 0.52762633 ... 0.59912768 0.60974563 0.53104052]
#     36)  gruppo_0/J98KmKGwcGFGxLh.wav  / label: 0 / freq: 16.0kHz / dim.: 64000 / data: [0.41949842 0.40762919 0.39304292 ... 0.48946249 0.49459271 0.4847434 ]
#     37)  gruppo_0/CFI9b1TkeLEAzKe.wav  / label: 0 / freq: 16.0kHz / dim.: 64000 / data: [0.53198792 0.53454409 0.53683213 ... 0.52807322 0.53173766 0.53440109]
#     38)  gruppo_0/mkGFfGA3VPOjgY4.wav  / label: 0 / freq: 16.0kHz / dim.: 64000 / data: [0.5340257  0.53429383 0.53422233 ... 0.53318556 0.53377545 0.53431171]
#     39)  gruppo_0/JrW4YPcnoSDgYke.wav  / label: 0 / freq: 16.0kHz / dim.: 64000 / data: [0.54106859 0.53375757 0.53188066 ... 0.53407933 0.5445364  0.5480936 ]
#     40)  gruppo_0/NoNW9S6nYtjWtWk.wav  / label: 0 / freq: 16.0kHz / dim.: 64000 / data: [0.66943139 0.63500349 0.62449279 ... 0.51702626 0.5548326  0.54405377]
#     41)  gruppo_0/JvZ0R4QAmZTmGzE.wav  / label: 0 / freq: 16.0kHz / dim.: 64000 / data: [0.55626262 0.55771053 0.5601952  ... 0.53624225 0.53588474 0.53579536]
#     42)  gruppo_0/8wd36zliTGM8a3s.wav  / label: 0 / freq: 16.0kHz / dim.: 64000 / data: [0.44924298 0.6213646  0.52793021 ... 0.47798652 0.42112507 0.54378564]
#     43)  gruppo_0/ZJ3vjjQ2dXZwhDe.wav  / label: 0 / freq: 16.0kHz / dim.: 64000 / data: [0.60994226 0.61625226 0.62420678 ... 0.49580823 0.49804265 0.49428883]
#     44)  gruppo_0/L4tFBNQIDPGROV7.wav  / label: 0 / freq: 16.0kHz / dim.: 64000 / data: [0.53386483 0.53138015 0.52964625 ... 0.50855335 0.51085927 0.51977906]
#     45)  gruppo_0/DHx3TIDnq0ppg0E.wav  / label: 0 / freq: 16.0kHz / dim.: 64000 / data: [0.63789929 0.62819298 0.62815723 ... 0.58182436 0.56645157 0.5547611 ]
#     46)  gruppo_0/lMARxboIHjHwIwY.wav  / label: 0 / freq: 16.0kHz / dim.: 64000 / data: [0.46760095 0.47448296 0.47644924 ... 0.53223817 0.52676832 0.51868867]
#     47)  gruppo_0/ucXKW2eoT9JI9PO.wav  / label: 0 / freq: 16.0kHz / dim.: 64000 / data: [0.53350732 0.53281018 0.53225605 ... 0.53685001 0.53651038 0.53661763]
#     48)  gruppo_0/WjGqoEHTolpgmpc.wav  / label: 0 / freq: 16.0kHz / dim.: 64000 / data: [0.53609924 0.53061152 0.53130865 ... 0.536564   0.53220242 0.53583111]
#     49)  gruppo_0/zdeo35n3reKl3gZ.wav  / label: 0 / freq: 16.0kHz / dim.: 64000 / data: [0.5363495  0.53679638 0.53575961 ... 0.53683213 0.53688576 0.5377974 ]
#     50)  gruppo_0/Hlb833lZHmwHovw.wav  / label: 0 / freq: 16.0kHz / dim.: 64000 / data: [0.52078008 0.51974331 0.51977906 ... 0.53272081 0.53331069 0.5325063 ]
#     51)  gruppo_0/a4WqBbSSUr1F16M.wav  / label: 0 / freq: 16.0kHz / dim.: 64000 / data: [0.49552223 0.48653093 0.48188335 ... 0.59374721 0.58323651 0.61371396]
#     52)  gruppo_0/rHzlLAio8ZVMsJn.wav  / label: 0 / freq: 16.0kHz / dim.: 64000 / data: [0.63516436 0.48694207 0.46878072 ... 0.52213861 0.47180166 0.65237831]
#     53)  gruppo_0/26y5R9ubyOuq0N9.wav  / label: 0 / freq: 16.0kHz / dim.: 64000 / data: [0.55887242 0.51979694 0.46670718 ... 0.52190623 0.51305793 0.51450584]
#     54)  gruppo_0/qAyEaFNjAzVuYzL.wav  / label: 0 / freq: 16.0kHz / dim.: 64000 / data: [0.53288168 0.52001144 0.51954668 ... 0.53475859 0.54121159 0.53981731]
#     55)  gruppo_0/5kSOvkXws5NGUaY.wav  / label: 0 / freq: 16.0kHz / dim.: 64000 / data: [0.56167885 0.56239387 0.55499348 ... 0.58001895 0.58591781 0.58320076]
#     56)  gruppo_0/dFrQ2rCvevym1BK.wav  / label: 0 / freq: 16.0kHz / dim.: 64000 / data: [0.48946249 0.50097421 0.52437302 ... 0.52778721 0.48529753 0.45387269]
#     57)  gruppo_0/JEd4S2iH1ESKyLJ.wav  / label: 0 / freq: 16.0kHz / dim.: 64000 / data: [0.58557818 0.56486066 0.54627031 ... 0.52952112 0.55805016 0.53559873]
#     58)  gruppo_0/9mZ35SDNqGMEyOo.wav  / label: 0 / freq: 16.0kHz / dim.: 64000 / data: [0.50635468 0.47879091 0.50799921 ... 0.54142609 0.53175554 0.52896698]
#     59)  gruppo_0/JJqWwQBbkf6KtO6.wav  / label: 0 / freq: 16.0kHz / dim.: 64000 / data: [0.55148991 0.56525392 0.56952612 ... 0.50510341 0.52063708 0.54015695]
#     60)  gruppo_0/8BsXJMX2PWABYua.wav  / label: 0 / freq: 16.0kHz / dim.: 64000 / data: [0.54094346 0.53853029 0.53597412 ... 0.55790716 0.55878305 0.5575854 ]
#     61)  gruppo_0/Fat17ZO0iQueiR1.wav  / label: 0 / freq: 16.0kHz / dim.: 64000 / data: [0.53570599 0.53661763 0.54142609 ... 0.52977137 0.53073664 0.53197004]
#     62)  gruppo_0/LhL9QDLaHjp25Gc.wav  / label: 0 / freq: 16.0kHz / dim.: 64000 / data: [0.49057076 0.57642601 0.54879073 ... 0.5697585  0.57186779 0.57138516]
#     63)  gruppo_0/S8ckB2vZdBU9KOD.wav  / label: 0 / freq: 16.0kHz / dim.: 64000 / data: [0.53220242 0.53071877 0.53071877 ... 0.54299912 0.54324938 0.54557317]
#     64)  gruppo_0/J8KLsllq1XsUMCq.wav  / label: 0 / freq: 16.0kHz / dim.: 64000 / data: [0.53188066 0.54764671 0.5533847  ... 0.52574942 0.549899   0.55427846]
#     65)  gruppo_0/sNnVsqR6UZ9EiM6.wav  / label: 0 / freq: 16.0kHz / dim.: 64000 / data: [0.57712314 0.57204655 0.59040452 ... 0.55604812 0.55054252 0.53715389]
#     66)  gruppo_0/juSaFo285Ib52Sn.wav  / label: 0 / freq: 16.0kHz / dim.: 64000 / data: [0.53406146 0.53398995 0.53416871 ... 0.86934916 0.84704074 0.62517205]
#     67)  gruppo_0/CyUfQRzluS8bCn1.wav  / label: 0 / freq: 16.0kHz / dim.: 64000 / data: [0.53506247 0.53672488 0.53769015 ... 0.56661244 0.57299394 0.58248574]
#     68)  gruppo_0/MYVJligwCu59dSj.wav  / label: 0 / freq: 16.0kHz / dim.: 64000 / data: [0.47358919 0.46256011 0.48585167 ... 0.52794809 0.52944962 0.52254974]
#     69)  gruppo_0/gRzgYnJpZAkyPUl.wav  / label: 0 / freq: 16.0kHz / dim.: 64000 / data: [0.51538173 0.51738377 0.5194573  ... 0.53255993 0.53116565 0.53146953]
#     70)  gruppo_0/tBognud8F1IrRA8.wav  / label: 0 / freq: 16.0kHz / dim.: 64000 / data: [0.52909211 0.53491947 0.53967431 ... 0.54130097 0.54119372 0.53121928]
#     71)  gruppo_0/5Ne7xfO16f4k7qj.wav  / label: 0 / freq: 16.0kHz / dim.: 64000 / data: [0.556495   0.55887242 0.53672488 ... 0.51833116 0.50948287 0.57408434]
#     72)  gruppo_0/RQJiuzj60eJnhoV.wav  / label: 0 / freq: 16.0kHz / dim.: 64000 / data: [0.52426577 0.52440877 0.52365801 ... 0.39252453 0.38263947 0.37947554]
#     73)  gruppo_0/pHG9WUQX8jRrn66.wav  / label: 0 / freq: 16.0kHz / dim.: 64000 / data: [0.46642118 0.44711581 0.44859947 ... 0.57109915 0.57188567 0.57002663]
#     74)  gruppo_0/3JdN0c5EMrjf9FB.wav  / label: 0 / freq: 16.0kHz / dim.: 64000 / data: [0.50860697 0.51752677 0.5243909  ... 0.4753946  0.51604312 0.56377027]
#     75)  gruppo_0/rsnvaWVfI1oizSJ.wav  / label: 0 / freq: 16.0kHz / dim.: 64000 / data: [0.51911767 0.51652575 0.52862735 ... 0.53770802 0.53597412 0.5392453 ]
#     76)  gruppo_0/Zr5YOVsmI32LnLn.wav  / label: 0 / freq: 16.0kHz / dim.: 64000 / data: [0.58906387 0.59485548 0.59589225 ... 0.52737608 0.53207729 0.53100477]
#     77)  gruppo_0/jp4Dxr256LlnFpc.wav  / label: 0 / freq: 16.0kHz / dim.: 64000 / data: [0.5708489  0.54217686 0.50149259 ... 0.510037   0.55788928 0.56591531]
#     78)  gruppo_0/R8p6GELwbxIQn6I.wav  / label: 0 / freq: 16.0kHz / dim.: 64000 / data: [0.53810128 0.54299912 0.54035357 ... 0.5375829  0.55334894 0.56321613]
#     79)  gruppo_0/Vl4BZPNxtu3hM2W.wav  / label: 0 / freq: 16.0kHz / dim.: 64000 / data: [0.49634449 0.62915825 0.5419266  ... 0.46649268 0.51130615 0.51588224]
#     80)  gruppo_0/w3AGSVaCpcvr5Py.wav  / label: 0 / freq: 16.0kHz / dim.: 64000 / data: [0.52049407 0.52129846 0.52560642 ... 0.55165079 0.55926568 0.55754965]
#     81)  gruppo_0/sXSSEYVwhpL4RkN.wav  / label: 0 / freq: 16.0kHz / dim.: 64000 / data: [0.52108396 0.49893642 0.54208748 ... 0.5363495  0.53454409 0.54478666]
#     82)  gruppo_0/KtAu9KxQexx2lc9.wav  / label: 0 / freq: 16.0kHz / dim.: 64000 / data: [0.53558086 0.53777953 0.54798634 ... 0.53304256 0.52029745 0.51990419]
#     83)  gruppo_0/ABmTMZqfV19vVeR.wav  / label: 0 / freq: 16.0kHz / dim.: 64000 / data: [0.53154103 0.53314981 0.53595624 ... 0.52548129 0.52878823 0.5311299 ]
#     84)  gruppo_0/gkdgr0aRKcGCox2.wav  / label: 0 / freq: 16.0kHz / dim.: 64000 / data: [0.51223567 0.50953649 0.50490678 ... 0.52632143 0.53114778 0.53752927]
#     85)  gruppo_0/KzhsJVacgUOebnP.wav  / label: 0 / freq: 16.0kHz / dim.: 64000 / data: [0.5180809  0.52072645 0.52119121 ... 0.59117316 0.58781259 0.59004701]
#     86)  gruppo_0/a2IWY3bO0uPCmnC.wav  / label: 0 / freq: 16.0kHz / dim.: 64000 / data: [0.52063708 0.51859929 0.53643888 ... 0.53854817 0.54641331 0.54621668]
#     87)  gruppo_0/I8rYp1p1t7YN41P.wav  / label: 0 / freq: 16.0kHz / dim.: 64000 / data: [0.52204923 0.50238636 0.52451603 ... 0.54711045 0.54768246 0.54807572]
#     88)  gruppo_0/5jF2rfeO9MBGBuN.wav  / label: 0 / freq: 16.0kHz / dim.: 64000 / data: [0.4821336  0.46767245 0.44098457 ... 0.52306812 0.52769784 0.54932699]
#     89)  gruppo_0/p0YdZUMn7xbszh9.wav  / label: 0 / freq: 16.0kHz / dim.: 64000 / data: [0.54673507 0.55059614 0.5456983  ... 0.55973044 0.57755215 0.55994494]
#     90)  gruppo_0/masP5bPPjfYQNqK.wav  / label: 0 / freq: 16.0kHz / dim.: 64000 / data: [0.53291743 0.53096902 0.53456196 ... 0.5733157  0.57630088 0.5762115 ]
#     91)  gruppo_0/zVcXUjHYJWpTCsV.wav  / label: 0 / freq: 16.0kHz / dim.: 64000 / data: [0.6302129  0.61282019 0.59417622 ... 0.41100763 0.42977674 0.45885991]
#     92)  gruppo_0/w3ZrXKSpKE0rPV8.wav  / label: 0 / freq: 16.0kHz / dim.: 64000 / data: [0.51413045 0.51330819 0.51398745 ... 0.53997819 0.53424021 0.53084389]
#     93)  gruppo_0/bhwPcCN7CCeMVY5.wav  / label: 0 / freq: 16.0kHz / dim.: 64000 / data: [0.80269203 0.80603471 0.81230896 ... 0.55293781 0.55647713 0.55871155]
#     94)  gruppo_0/XOIh1pZFvrhuchb.wav  / label: 0 / freq: 16.0kHz / dim.: 64000 / data: [0.46239923 0.44506015 0.42330586 ... 0.57887493 0.59791216 0.61859393]
#     95)  gruppo_0/KwLcSy1YsYTL3aZ.wav  / label: 0 / freq: 16.0kHz / dim.: 64000 / data: [0.56995513 0.52507016 0.52414064 ... 0.52712582 0.51690113 0.55458234]
#     96)  gruppo_0/24y855VJHUgRlPq.wav  / label: 0 / freq: 16.0kHz / dim.: 64000 / data: [0.4810432  0.5006167  0.5140947  ... 0.49911517 0.51811665 0.55181167]
#     97)  gruppo_0/HjCf21GrQIOrm8y.wav  / label: 0 / freq: 16.0kHz / dim.: 64000 / data: [0.60972776 0.59422984 0.59199542 ... 0.616145   0.59725077 0.57456697]
#     98)  gruppo_0/f9kUoUR09guTuU8.wav  / label: 0 / freq: 16.0kHz / dim.: 64000 / data: [0.64812398 0.63096366 0.6370234  ... 0.52385464 0.49462846 0.5920133 ]
#     99)  gruppo_0/lVV4HAIzdtLVNkG.wav  / label: 0 / freq: 16.0kHz / dim.: 64000 / data: [0.53111202 0.50807071 0.53307831 ... 0.53740414 0.53230967 0.53232755]
#    100)  gruppo_0/UVtFRxX7Hq0iEsm.wav  / label: 0 / freq: 16.0kHz / dim.: 64000 / data: [0.60123697 0.55567274 0.50538941 ... 0.53704664 0.45251417 0.48265199]
#    101)  gruppo_0/9mqDe1Z1VNLJ596.wav  / label: 0 / freq: 16.0kHz / dim.: 64000 / data: [0.53012888 0.53420446 0.51700838 ... 0.48617343 0.60724309 0.58318288]
#    102)  gruppo_0/DEMAtwHFpSf0yXO.wav  / label: 0 / freq: 16.0kHz / dim.: 64000 / data: [0.54219473 0.54342813 0.53858392 ... 0.58227124 0.58291475 0.57290456]
#    103)  gruppo_0/bMmZuh8pv0CVC9S.wav  / label: 0 / freq: 16.0kHz / dim.: 64000 / data: [0.50242211 0.53556298 0.50156409 ... 0.45809127 0.52964625 0.67849418]
#    104)  gruppo_0/95M8iP0tOHytare.wav  / label: 0 / freq: 16.0kHz / dim.: 64000 / data: [0.52617843 0.52104821 0.51522085 ... 0.5375114  0.53309619 0.53109415]
#    105)  gruppo_0/Ny5WhFEfMj9mjfv.wav  / label: 0 / freq: 16.0kHz / dim.: 64000 / data: [0.53726114 0.53810128 0.53661763 ... 0.53391845 0.53350732 0.5336682 ]
#    106)  gruppo_0/HjnHoLmEZEZ05JT.wav  / label: 0 / freq: 16.0kHz / dim.: 64000 / data: [0.5136657  0.52131634 0.50538941 ... 0.54929124 0.55588724 0.53436534]
#    107)  gruppo_0/obQwF9AGQVyxtBg.wav  / label: 0 / freq: 16.0kHz / dim.: 64000 / data: [0.50783834 0.51062689 0.51205692 ... 0.49439608 0.48134709 0.47448296]
#    108)  gruppo_0/nV0V85HoGvKRGI0.wav  / label: 0 / freq: 16.0kHz / dim.: 64000 / data: [0.54314213 0.53838729 0.53406146 ... 0.52004719 0.50703395 0.52347926]
#    109)  gruppo_0/hGEoQ1ouW6OPW8V.wav  / label: 0 / freq: 16.0kHz / dim.: 64000 / data: [0.51414833 0.51286131 0.51346907 ... 0.51933218 0.5177234  0.50656919]
#    110)  gruppo_0/VaACIM5ERBd4MAq.wav  / label: 0 / freq: 16.0kHz / dim.: 64000 / data: [0.54210536 0.51838478 0.47265967 ... 0.47845128 0.47982768 0.48940886]
#    111)  gruppo_0/TUgokLJCWzFLplR.wav  / label: 0 / freq: 16.0kHz / dim.: 64000 / data: [0.55191892 0.55072127 0.55011351 ... 0.55828254 0.56407415 0.56832848]
#    112)  gruppo_0/VgaDHligKhOl56B.wav  / label: 0 / freq: 16.0kHz / dim.: 64000 / data: [0.56007007 0.55415333 0.4994548  ... 0.47854066 0.50249361 0.52360438]
#    113)  gruppo_0/ipxWXTpmRzppIAr.wav  / label: 0 / freq: 16.0kHz / dim.: 64000 / data: [0.74513344 0.50696244 0.4291511  ... 0.52628568 0.51879592 0.50429902]
#    114)  gruppo_0/EN05akeI0B0LCRP.wav  / label: 0 / freq: 16.0kHz / dim.: 64000 / data: [0.53207729 0.54818297 0.55551186 ... 0.5430885  0.53994244 0.52855585]
#    115)  gruppo_0/CFxG6tT3R3e5eZY.wav  / label: 0 / freq: 16.0kHz / dim.: 64000 / data: [0.55256243 0.55365283 0.54727133 ... 0.54246286 0.55161504 0.54812935]
#    116)  gruppo_0/GjvwNoI4vjdGl19.wav  / label: 0 / freq: 16.0kHz / dim.: 64000 / data: [0.55803228 0.56984788 0.59776916 ... 0.5338827  0.53679638 0.53302469]
#    117)  gruppo_0/fiTo00pnt11reXg.wav  / label: 0 / freq: 16.0kHz / dim.: 64000 / data: [0.46951361 0.57771303 0.60516955 ... 0.50882148 0.5138802  0.51881379]
#    118)  gruppo_0/KBLrmiET6BHGXf8.wav  / label: 0 / freq: 16.0kHz / dim.: 64000 / data: [0.51699051 0.523372   0.5269292  ... 0.56105321 0.54187298 0.56755984]
#    119)  gruppo_0/2x7llOY2QY5mPUZ.wav  / label: 0 / freq: 16.0kHz / dim.: 64000 / data: [0.57292244 0.569401   0.56550417 ... 0.51956456 0.52317537 0.51289706]
#    120)  gruppo_0/hAnriiopppJehir.wav  / label: 0 / freq: 16.0kHz / dim.: 64000 / data: [0.49600486 0.49103552 0.50588992 ... 0.55622687 0.54988113 0.55638775]
#    121)  gruppo_0/0JpgBKUa88Uy7Os.wav  / label: 0 / freq: 16.0kHz / dim.: 64000 / data: [0.52498078 0.52607118 0.51877804 ... 0.52549917 0.51961818 0.52437302]
#    122)  gruppo_0/zfyCEIsvLBaCtS9.wav  / label: 0 / freq: 16.0kHz / dim.: 64000 / data: [0.53336432 0.53838729 0.54466153 ... 0.55057827 0.5510609  0.55031014]
#    123)  gruppo_0/5H29DCCqosKp9Cx.wav  / label: 0 / freq: 16.0kHz / dim.: 64000 / data: [0.49087464 0.57168904 0.60525892 ... 0.50542516 0.49981231 0.52158447]
#    124)  gruppo_0/wG8nuwBgEzgP0HT.wav  / label: 0 / freq: 16.0kHz / dim.: 64000 / data: [0.54262374 0.54382139 0.54346388 ... 0.53988882 0.53922743 0.53742202]
#    125)  gruppo_0/OwxvEztvwd2Uogo.wav  / label: 0 / freq: 16.0kHz / dim.: 64000 / data: [0.51775915 0.51863504 0.52633931 ... 0.47841553 0.49612999 0.51280768]
#    126)  gruppo_0/Fek1WLPq6zoyu3x.wav  / label: 0 / freq: 16.0kHz / dim.: 64000 / data: [0.51116315 0.51781277 0.51368357 ... 0.48107896 0.48613768 0.48901561]
#    127)  gruppo_0/ZAi9aNYJJG3qei5.wav  / label: 0 / freq: 16.0kHz / dim.: 64000 / data: [0.53145166 0.54762884 0.54521567 ... 0.51341544 0.50004469 0.48613768]
#    128)  gruppo_0/QIIYmdyQpSbZ5ma.wav  / label: 0 / freq: 16.0kHz / dim.: 64000 / data: [0.56105321 0.57379833 0.58901024 ... 0.50281537 0.49907942 0.51411258]
#    129)  gruppo_0/nSPy9BItjaNiX3h.wav  / label: 0 / freq: 16.0kHz / dim.: 64000 / data: [0.57138516 0.60286363 0.5974474  ... 0.55971256 0.54459003 0.62402803]
#    130)  gruppo_0/jz6SYfBfpAPmOgo.wav  / label: 0 / freq: 16.0kHz / dim.: 64000 / data: [0.5180094  0.51904617 0.52510591 ... 0.38601791 0.38655417 0.38753731]
#    131)  gruppo_0/EbJ7PMDPTnQwsBh.wav  / label: 0 / freq: 16.0kHz / dim.: 64000 / data: [0.53724327 0.53838729 0.53920955 ... 0.52573155 0.53581324 0.54441128]
#    132)  gruppo_0/XuPJ1kFgRdkNcVY.wav  / label: 0 / freq: 16.0kHz / dim.: 64000 / data: [0.53558086 0.53440109 0.5336682  ... 0.53452621 0.53350732 0.53361457]
#    133)  gruppo_0/MoudmEDSnJRFg9h.wav  / label: 0 / freq: 16.0kHz / dim.: 64000 / data: [0.5485941  0.55599449 0.55844342 ... 0.54557317 0.5443219  0.53574174]
#    134)  gruppo_0/SOdsg3wj4zToDXX.wav  / label: 0 / freq: 16.0kHz / dim.: 64000 / data: [0.60736821 0.64306526 0.63856068 ... 0.54133672 0.53831579 0.54001394]
#    135)  gruppo_0/4aSXeYoHfuUBpLw.wav  / label: 0 / freq: 16.0kHz / dim.: 64000 / data: [0.50571117 0.54637756 0.57472785 ... 0.53188066 0.53506247 0.53531273]
#    136)  gruppo_0/7K8vuARFwiEJBHr.wav  / label: 0 / freq: 16.0kHz / dim.: 64000 / data: [0.53674276 0.52607118 0.52215648 ... 0.59355058 0.50642618 0.51371932]
#    137)  gruppo_0/nFiP4yOavfAjEeW.wav  / label: 0 / freq: 16.0kHz / dim.: 64000 / data: [0.45716175 0.51616824 0.59124466 ... 0.51536385 0.50524641 0.51062689]
#    138)  gruppo_0/sF3fNPADWfhsUPy.wav  / label: 0 / freq: 16.0kHz / dim.: 64000 / data: [0.62429616 0.62265163 0.63182168 ... 0.67881594 0.68301664 0.69082816]
#    139)  gruppo_0/kYcuAYoO1JbYw7F.wav  / label: 0 / freq: 16.0kHz / dim.: 64000 / data: [0.53064727 0.5298965  0.52868098 ... 0.53457984 0.53436534 0.5338827 ]
#    140)  gruppo_0/lEOusLXNWADxpgD.wav  / label: 0 / freq: 16.0kHz / dim.: 64000 / data: [0.53354307 0.53708239 0.54923762 ... 0.58144897 0.55740665 0.47117602]
#    141)  gruppo_0/TQAP0JBlUWQA4pv.wav  / label: 0 / freq: 16.0kHz / dim.: 64000 / data: [0.62804998 0.63407397 0.63275119 ... 0.57403071 0.57347657 0.57213592]
#    142)  gruppo_0/BEt4DY5PlVbsny3.wav  / label: 0 / freq: 16.0kHz / dim.: 64000 / data: [0.49521835 0.57047352 0.4690846  ... 0.53506247 0.53890567 0.53797615]
#    143)  gruppo_0/JLfwM5AryXKRhgC.wav  / label: 0 / freq: 16.0kHz / dim.: 64000 / data: [0.53425808 0.53422233 0.53420446 ... 0.53536636 0.54240924 0.53874479]
#    144)  gruppo_0/mN9m34eenLUue6M.wav  / label: 0 / freq: 16.0kHz / dim.: 64000 / data: [0.5998427  0.59671451 0.56654094 ... 0.58457716 0.53726114 0.57808841]
#    145)  gruppo_0/vInGngvVp0ruSpM.wav  / label: 0 / freq: 16.0kHz / dim.: 64000 / data: [0.50942924 0.51795578 0.52254974 ... 0.58707971 0.52925299 0.48333125]
#    146)  gruppo_0/y5M18TK5hkaDcUf.wav  / label: 0 / freq: 16.0kHz / dim.: 64000 / data: [0.59782278 0.5657008  0.54669932 ... 0.50016982 0.48268774 0.49434246]
#    147)  gruppo_0/aF8I8hDrlWDeDYh.wav  / label: 0 / freq: 16.0kHz / dim.: 64000 / data: [0.55016713 0.55574424 0.55588724 ... 0.54155122 0.54162272 0.54144397]
#    148)  gruppo_0/WDFBVxdnZQj2rxn.wav  / label: 0 / freq: 16.0kHz / dim.: 64000 / data: [0.55090002 0.57136728 0.60920937 ... 0.4754661  0.53579536 0.49411008]
#    149)  gruppo_0/TW7V1MMETtv8klz.wav  / label: 0 / freq: 16.0kHz / dim.: 64000 / data: [0.54314213 0.5388163  0.54169422 ... 0.57449547 0.55268756 0.54605581]
#    150)  gruppo_0/1EQD6viUfa2KVqi.wav  / label: 0 / freq: 16.0kHz / dim.: 64000 / data: [0.60475841 0.60710008 0.60184473 ... 0.58615019 0.5946946  0.59303219]
#    151)  gruppo_0/5uPqq7WoOPebrw4.wav  / label: 1 / freq: 16.0kHz / dim.: 64000 / data: [0.53046851 0.5259818  0.52052983 ... 0.53407933 0.53406146 0.53407933]
#    152)  gruppo_0/xz8Bhl0xiwAhoyT.wav  / label: 1 / freq: 16.0kHz / dim.: 64000 / data: [0.56609406 0.55460022 0.53173766 ... 0.54414315 0.54668144 0.55974832]
#    153)  gruppo_0/zbKBXyTZj26dujc.wav  / label: 1 / freq: 16.0kHz / dim.: 64000 / data: [0.59439072 0.59968182 0.61046065 ... 0.5340257  0.5340257  0.53397208]
#    154)  gruppo_0/q0mcOT9Rw9bzK3g.wav  / label: 1 / freq: 16.0kHz / dim.: 64000 / data: [0.51175303 0.49459271 0.50363763 ... 0.53976369 0.52939599 0.52110184]
#    155)  gruppo_0/pnAe3YO4prMG8gP.wav  / label: 1 / freq: 16.0kHz / dim.: 64000 / data: [0.52006507 0.52203135 0.5296105  ... 0.50855335 0.50201098 0.50231486]
#    156)  gruppo_0/i44XehE5vcoaOgk.wav  / label: 1 / freq: 16.0kHz / dim.: 64000 / data: [0.57435247 0.57832079 0.57731977 ... 0.53447259 0.53441896 0.53445471]
#    157)  gruppo_0/OC2wkHuzeo0kYBi.wav  / label: 1 / freq: 16.0kHz / dim.: 64000 / data: [0.6212216  0.63816742 0.64011583 ... 0.53661763 0.53558086 0.53960281]
#    158)  gruppo_0/5ICIskSNKgdivxE.wav  / label: 1 / freq: 16.0kHz / dim.: 64000 / data: [0.53327494 0.54078258 0.53481222 ... 0.5352591  0.53279231 0.54176573]
#    159)  gruppo_0/7fOo4xzQGfDGwzu.wav  / label: 1 / freq: 16.0kHz / dim.: 64000 / data: [0.52719733 0.54269524 0.55844342 ... 0.53424021 0.53424021 0.53425808]
#    160)  gruppo_0/bL4J1e30T0zlM9g.wav  / label: 1 / freq: 16.0kHz / dim.: 64000 / data: [0.53456196 0.53450834 0.53450834 ... 0.53398995 0.5340257  0.53397208]
#    161)  gruppo_0/p0S71JAmbivQatf.wav  / label: 1 / freq: 16.0kHz / dim.: 64000 / data: [0.5454838  0.5406217  0.53729689 ... 0.56148222 0.56495004 0.56865023]
#    162)  gruppo_0/zynn9IYkGTQc7fH.wav  / label: 1 / freq: 16.0kHz / dim.: 64000 / data: [0.52006507 0.54680657 0.54627031 ... 0.5680246  0.55869367 0.55166866]
#    163)  gruppo_0/sDkTICUqfDKBsAt.wav  / label: 1 / freq: 16.0kHz / dim.: 64000 / data: [0.58101997 0.60050408 0.59816242 ... 0.45222816 0.45492734 0.45221029]
#    164)  gruppo_0/w79zxKTOim2Y6C4.wav  / label: 1 / freq: 16.0kHz / dim.: 64000 / data: [0.53334644 0.53266718 0.53163041 ... 0.54991688 0.55197254 0.55234793]
#    165)  gruppo_0/VqHIZqCtesHUIp7.wav  / label: 1 / freq: 16.0kHz / dim.: 64000 / data: [0.57873192 0.57176054 0.56621919 ... 0.51967181 0.52011869 0.52489141]
#    166)  gruppo_0/QeYTWrYkgarpxD3.wav  / label: 1 / freq: 16.0kHz / dim.: 64000 / data: [0.47494771 0.46960299 0.46606367 ... 0.53288168 0.51629337 0.49369894]
#    167)  gruppo_0/TgO2D9AnSlSmnrh.wav  / label: 1 / freq: 16.0kHz / dim.: 64000 / data: [0.56014157 0.58395152 0.59203117 ... 0.55317019 0.55569061 0.55713852]
#    168)  gruppo_0/9Gf0MjMEdUskJ3L.wav  / label: 1 / freq: 16.0kHz / dim.: 64000 / data: [0.46166634 0.45757289 0.45766226 ... 0.52973562 0.54038932 0.53976369]
#    169)  gruppo_0/983ios6wMqeoJ8Q.wav  / label: 1 / freq: 16.0kHz / dim.: 64000 / data: [0.5190998  0.51824178 0.51745527 ... 0.53990669 0.54305275 0.549756  ]
#    170)  gruppo_0/DWKvuSRNrDoIfuo.wav  / label: 1 / freq: 16.0kHz / dim.: 64000 / data: [0.53372182 0.53247055 0.53413296 ... 0.47085426 0.5137372  0.53969219]
#    171)  gruppo_0/7FGsQAlddnkCA5w.wav  / label: 1 / freq: 16.0kHz / dim.: 64000 / data: [0.53238117 0.54628819 0.57190354 ... 0.66632108 0.66946714 0.65380834]
#    172)  gruppo_0/o5pMDsw3FbQbgDj.wav  / label: 1 / freq: 16.0kHz / dim.: 64000 / data: [0.52306812 0.52444452 0.53045064 ... 0.53643888 0.53499097 0.53391845]
#    173)  gruppo_0/mV24zBYXhOZA2Nh.wav  / label: 1 / freq: 16.0kHz / dim.: 64000 / data: [0.54335663 0.52414064 0.50664069 ... 0.60112972 0.57757003 0.55485047]
#    174)  gruppo_0/jgiXy1o2qn85MoU.wav  / label: 1 / freq: 16.0kHz / dim.: 64000 / data: [0.5127898  0.51059114 0.50926836 ... 0.54866561 0.55526161 0.5603382 ]
#    175)  gruppo_0/6iVx2doRsxhausx.wav  / label: 1 / freq: 16.0kHz / dim.: 64000 / data: [0.46449064 0.46214897 0.4648839  ... 0.52803747 0.5376544  0.54065745]
#    176)  gruppo_0/XSdQ3bmxZ4VISXY.wav  / label: 1 / freq: 16.0kHz / dim.: 64000 / data: [0.53415083 0.53466922 0.53527698 ... 0.5575139  0.5590333  0.55992707]
#    177)  gruppo_0/XUeRZG5Jza4ehls.wav  / label: 1 / freq: 16.0kHz / dim.: 64000 / data: [0.5944801  0.56080296 0.54285612 ... 0.53513398 0.53397208 0.53320344]
#    178)  gruppo_0/iwaiRwIP2g1QY0D.wav  / label: 1 / freq: 16.0kHz / dim.: 64000 / data: [0.56335913 0.56360939 0.56310888 ... 0.53415083 0.53415083 0.53413296]
#    179)  gruppo_0/LLO2bsEDLXrwVNH.wav  / label: 1 / freq: 16.0kHz / dim.: 64000 / data: [0.59894893 0.60034321 0.58768747 ... 0.52712582 0.53559873 0.5445364 ]
#    180)  gruppo_0/2r40aV5VnntOkvi.wav  / label: 1 / freq: 16.0kHz / dim.: 64000 / data: [0.53406146 0.53436534 0.53422233 ... 0.53241692 0.53248843 0.53248843]
#    181)  gruppo_0/iv8rikFGFapqryT.wav  / label: 1 / freq: 16.0kHz / dim.: 64000 / data: [0.53565236 0.53575961 0.53577749 ... 0.49902579 0.49280518 0.48912286]
#    182)  gruppo_0/hMvn4jmsjPhvYtT.wav  / label: 1 / freq: 16.0kHz / dim.: 64000 / data: [0.52419427 0.53472284 0.53756502 ... 0.50478165 0.49722039 0.48538691]
#    183)  gruppo_0/PhTWnHjhBvU8gVd.wav  / label: 1 / freq: 16.0kHz / dim.: 64000 / data: [0.48901561 0.48249111 0.47491196 ... 0.53375757 0.51741952 0.49698801]
#    184)  gruppo_0/vfjoBO9yvmFi81W.wav  / label: 1 / freq: 16.0kHz / dim.: 64000 / data: [0.53407933 0.5270007  0.52326475 ... 0.53962069 0.52819834 0.51375507]
#    185)  gruppo_0/dZmqs0g8UocMvj5.wav  / label: 1 / freq: 16.0kHz / dim.: 64000 / data: [0.55906905 0.55819316 0.55551186 ... 0.54085408 0.53223817 0.529825  ]
#    186)  gruppo_0/HKT6NWvnVwF0bZg.wav  / label: 1 / freq: 16.0kHz / dim.: 64000 / data: [0.48663819 0.48442164 0.48313462 ... 0.53745777 0.54046083 0.53788678]
#    187)  gruppo_0/om9HqN21H5agPnx.wav  / label: 1 / freq: 16.0kHz / dim.: 64000 / data: [0.53413296 0.53415083 0.53415083 ... 0.53415083 0.53415083 0.53415083]
#    188)  gruppo_0/tD0Mrsx8ixRhL3y.wav  / label: 1 / freq: 16.0kHz / dim.: 64000 / data: [0.47419695 0.51035876 0.52619631 ... 0.49671988 0.48967699 0.48258048]
#    189)  gruppo_0/gI6rj4oahILoPen.wav  / label: 1 / freq: 16.0kHz / dim.: 64000 / data: [0.53415083 0.53415083 0.53415083 ... 0.61206943 0.57143879 0.55081065]
#    190)  gruppo_0/I105f7l6rMzenTt.wav  / label: 1 / freq: 16.0kHz / dim.: 64000 / data: [0.48156159 0.46334662 0.45508821 ... 0.57615787 0.57547861 0.57420946]
#    191)  gruppo_0/8oOHtYE4mKmpo13.wav  / label: 1 / freq: 16.0kHz / dim.: 64000 / data: [0.55692401 0.56750621 0.56832848 ... 0.5999142  0.61416084 0.61805767]
#    192)  gruppo_0/Q0yQtm8SQO1yRrT.wav  / label: 1 / freq: 16.0kHz / dim.: 64000 / data: [0.52015444 0.53182704 0.54512629 ... 0.57263643 0.59782278 0.58743721]
#    193)  gruppo_0/VJb7j7SXOQLI4h2.wav  / label: 1 / freq: 16.0kHz / dim.: 64000 / data: [0.53556298 0.53581324 0.53606349 ... 0.55182954 0.5444649  0.543017  ]
#    194)  gruppo_0/t5g3NXFpAou5KTc.wav  / label: 1 / freq: 16.0kHz / dim.: 64000 / data: [0.5335252  0.5336682  0.53375757 ... 0.53878054 0.53869117 0.53833366]
#    195)  gruppo_0/tfCCyGkUDC1vwEO.wav  / label: 1 / freq: 16.0kHz / dim.: 64000 / data: [0.53611712 0.53302469 0.53279231 ... 0.4888726  0.4858338  0.48787158]
#    196)  gruppo_0/tjYcNYTUkNQZzsJ.wav  / label: 1 / freq: 16.0kHz / dim.: 64000 / data: [0.53397208 0.53393633 0.53398995 ... 0.43887528 0.46189872 0.46588492]
#    197)  gruppo_0/ENOZpjU1pTi5b25.wav  / label: 1 / freq: 16.0kHz / dim.: 64000 / data: [0.62771035 0.61287382 0.60618844 ... 0.51974331 0.53255993 0.51228929]
#    198)  gruppo_0/OgOk8Iwzx0bwVOy.wav  / label: 1 / freq: 16.0kHz / dim.: 64000 / data: [0.5309869  0.5309869  0.53096902 ... 0.53340007 0.53343582 0.53341794]
#    199)  gruppo_0/0JCfXygQaAhMjjP.wav  / label: 1 / freq: 16.0kHz / dim.: 64000 / data: [0.53443684 0.53509822 0.53340007 ... 0.5388163  0.53139803 0.53833366]
#    200)  gruppo_0/Kj0JZeanVOEd8xK.wav  / label: 1 / freq: 16.0kHz / dim.: 64000 / data: [0.53415083 0.53413296 0.53415083 ... 0.52946749 0.53531273 0.53713601]
#    201)  gruppo_0/Jdpb8BaCNPZ1L6Y.wav  / label: 1 / freq: 16.0kHz / dim.: 64000 / data: [0.52889548 0.53064727 0.52682194 ... 0.52221011 0.5256243  0.52944962]
#    202)  gruppo_0/hRxfgZqtRvPrZv4.wav  / label: 1 / freq: 16.0kHz / dim.: 64000 / data: [0.55958744 0.5576569  0.55064977 ... 0.55990919 0.56500366 0.56820335]
#    203)  gruppo_0/BkF7aSuN5KRVwD7.wav  / label: 1 / freq: 16.0kHz / dim.: 64000 / data: [0.47534097 0.47503709 0.48147221 ... 0.52394401 0.53688576 0.54135459]
#    204)  gruppo_0/NZAERLA3b6T4Ar1.wav  / label: 1 / freq: 16.0kHz / dim.: 64000 / data: [0.50451352 0.51568561 0.53307831 ... 0.53413296 0.53415083 0.53415083]
#    205)  gruppo_0/XPZPFctLLqfFmah.wav  / label: 1 / freq: 16.0kHz / dim.: 64000 / data: [0.56525392 0.54993476 0.52896698 ... 0.50744508 0.51034088 0.51182454]
#    206)  gruppo_0/5N4xcJQsRjJeyIb.wav  / label: 1 / freq: 16.0kHz / dim.: 64000 / data: [0.45880628 0.48052482 0.50687307 ... 0.49212591 0.54142609 0.55695976]
#    207)  gruppo_0/PFS5dVtrnLLJl8y.wav  / label: 1 / freq: 16.0kHz / dim.: 64000 / data: [0.53398995 0.53393633 0.53341794 ... 0.56552205 0.56314463 0.55376008]
#    208)  gruppo_0/JfkFoTk3Gkv8546.wav  / label: 1 / freq: 16.0kHz / dim.: 64000 / data: [0.53255993 0.52365801 0.52044045 ... 0.55771053 0.58055521 0.59691114]
#    209)  gruppo_0/7kre3DjhKtwlIwE.wav  / label: 1 / freq: 16.0kHz / dim.: 64000 / data: [0.53197004 0.53202367 0.53214879 ... 0.54110434 0.55581574 0.55022076]
#    210)  gruppo_0/26op3rsPuxdrYXD.wav  / label: 1 / freq: 16.0kHz / dim.: 64000 / data: [0.48240173 0.48862235 0.51464884 ... 0.54337451 0.53334644 0.53055789]
#    211)  gruppo_0/ECeiTF26A0GT679.wav  / label: 1 / freq: 16.0kHz / dim.: 64000 / data: [0.57365533 0.56396689 0.56101746 ... 0.44003718 0.48874748 0.51196754]
#    212)  gruppo_0/TiExgsfbsu9FL1l.wav  / label: 1 / freq: 16.0kHz / dim.: 64000 / data: [0.53661763 0.53726114 0.53702876 ... 0.53175554 0.52110184 0.53184491]
#    213)  gruppo_0/tBluGoPmdsO8nNJ.wav  / label: 1 / freq: 16.0kHz / dim.: 64000 / data: [0.57202867 0.55252668 0.5298965  ... 0.43580073 0.42890085 0.43614036]
#    214)  gruppo_0/C3G4JfzCt5np5vt.wav  / label: 1 / freq: 16.0kHz / dim.: 64000 / data: [0.47782564 0.47898754 0.47364282 ... 0.53096902 0.53406146 0.5269292 ]
#    215)  gruppo_0/Pp7678v0l2cuUge.wav  / label: 1 / freq: 16.0kHz / dim.: 64000 / data: [0.57190354 0.58618594 0.59523086 ... 0.58148473 0.57199292 0.5509894 ]
#    216)  gruppo_0/qlhlW17m7ZC3Ik1.wav  / label: 1 / freq: 16.0kHz / dim.: 64000 / data: [0.49359169 0.48145434 0.49048138 ... 0.5998427  0.63484261 0.62822873]
#    217)  gruppo_0/qOrW9FvXRWbYRmZ.wav  / label: 1 / freq: 16.0kHz / dim.: 64000 / data: [0.50833884 0.51370145 0.5138087  ... 0.53933468 0.53920955 0.53976369]
#    218)  gruppo_0/gA2CQbJHBVdHsPA.wav  / label: 1 / freq: 16.0kHz / dim.: 64000 / data: [0.53810128 0.54190873 0.5406217  ... 0.54469728 0.54784334 0.56419927]
#    219)  gruppo_0/WFhBGlGRbWfg7e5.wav  / label: 1 / freq: 16.0kHz / dim.: 64000 / data: [0.56643369 0.5601237  0.5511324  ... 0.49200079 0.49484297 0.49541498]
#    220)  gruppo_0/yVqY30sNihtw15p.wav  / label: 1 / freq: 16.0kHz / dim.: 64000 / data: [0.477057   0.4938777  0.48526178 ... 0.55674526 0.55574424 0.55372433]
#    221)  gruppo_0/lpnHVkKxfvuHYBW.wav  / label: 1 / freq: 16.0kHz / dim.: 64000 / data: [0.56319826 0.56421715 0.56865023 ... 0.46352537 0.45399782 0.45489159]
#    222)  gruppo_0/gsApzqFe6ZI7teK.wav  / label: 1 / freq: 16.0kHz / dim.: 64000 / data: [0.53415083 0.53413296 0.53413296 ... 0.53777953 0.53777953 0.53711814]
#    223)  gruppo_0/wsrGf1x1BAjwJF3.wav  / label: 1 / freq: 16.0kHz / dim.: 64000 / data: [0.57127791 0.57385196 0.57689076 ... 0.5335967  0.53340007 0.53316769]
#    224)  gruppo_0/5KPVRrrcf3xwREn.wav  / label: 1 / freq: 16.0kHz / dim.: 64000 / data: [0.56457466 0.56124984 0.56175035 ... 0.50665856 0.50794559 0.50925049]
#    225)  gruppo_0/T8uJiz4GN98A0Md.wav  / label: 1 / freq: 16.0kHz / dim.: 64000 / data: [0.49679138 0.50129596 0.50640831 ... 0.59178092 0.57885705 0.56856086]
#    226)  gruppo_0/C7GLyjZaqVAXk1Z.wav  / label: 1 / freq: 16.0kHz / dim.: 64000 / data: [0.50277961 0.50560392 0.51545323 ... 0.54176573 0.54248074 0.542874  ]
#    227)  gruppo_0/aAay7aY6JT3jr98.wav  / label: 1 / freq: 16.0kHz / dim.: 64000 / data: [0.52153084 0.52256761 0.52356863 ... 0.46953149 0.47825465 0.48268774]
#    228)  gruppo_0/MVHrHaBU4kwSwOK.wav  / label: 1 / freq: 16.0kHz / dim.: 64000 / data: [0.53415083 0.53415083 0.53415083 ... 0.53413296 0.53413296 0.53413296]
#    229)  gruppo_0/k2xdiBCIIAb2Shj.wav  / label: 1 / freq: 16.0kHz / dim.: 64000 / data: [0.48949824 0.52846647 0.55570849 ... 0.53674276 0.53840516 0.5482366 ]
#    230)  gruppo_0/CazwkLphN5rtxR6.wav  / label: 1 / freq: 16.0kHz / dim.: 64000 / data: [0.53198792 0.55152566 0.56468191 ... 0.51007275 0.53102265 0.53838729]
#    231)  gruppo_0/5VIA1vRtrkOqzBs.wav  / label: 1 / freq: 16.0kHz / dim.: 64000 / data: [0.51690113 0.51659725 0.52741183 ... 0.53406146 0.53361457 0.53318556]
#    232)  gruppo_0/NxqNkCw1tEhxeNT.wav  / label: 1 / freq: 16.0kHz / dim.: 64000 / data: [0.57294031 0.56087446 0.53969219 ... 0.49750639 0.50395939 0.50004469]
#    233)  gruppo_0/pkGPsW09Pm1ThJF.wav  / label: 1 / freq: 16.0kHz / dim.: 64000 / data: [0.46129096 0.45660762 0.47421483 ... 0.61083603 0.60486567 0.59658939]
#    234)  gruppo_0/bCAGG0ogS6bsjhx.wav  / label: 1 / freq: 16.0kHz / dim.: 64000 / data: [0.52473053 0.52253186 0.51943943 ... 0.53270293 0.52753696 0.52950324]
#    235)  gruppo_0/X3o3OKYDpXDkVKY.wav  / label: 1 / freq: 16.0kHz / dim.: 64000 / data: [0.53559873 0.53609924 0.53584899 ... 0.54349963 0.54305275 0.54267737]
#    236)  gruppo_0/dVEKruT6TaKGkxv.wav  / label: 1 / freq: 16.0kHz / dim.: 64000 / data: [0.54641331 0.54895161 0.54934487 ... 0.53200579 0.52762633 0.52263911]
#    237)  gruppo_0/8Y85Y98CvT810X7.wav  / label: 1 / freq: 16.0kHz / dim.: 64000 / data: [0.54936274 0.50683732 0.47366069 ... 0.52221011 0.53565236 0.54957725]
#    238)  gruppo_0/MPtGUg4n26keiT5.wav  / label: 1 / freq: 16.0kHz / dim.: 64000 / data: [0.47716426 0.54866561 0.59583862 ... 0.56083871 0.53234542 0.49616574]
#    239)  gruppo_0/pn4fY5ejmfqYbwb.wav  / label: 1 / freq: 16.0kHz / dim.: 64000 / data: [0.42421751 0.4082012  0.3945802  ... 0.51616824 0.529825   0.52262124]
#    240)  gruppo_0/rwFHVC11GG4mecJ.wav  / label: 1 / freq: 16.0kHz / dim.: 64000 / data: [0.49393132 0.49201866 0.48955187 ... 0.53449046 0.53479434 0.5403357 ]
#    241)  gruppo_0/ffRW7hnNavsbNqk.wav  / label: 1 / freq: 16.0kHz / dim.: 64000 / data: [0.53415083 0.53413296 0.53413296 ... 0.58697245 0.59782278 0.58995764]
#    242)  gruppo_0/bKZhFxueh50m7W1.wav  / label: 1 / freq: 16.0kHz / dim.: 64000 / data: [0.53720751 0.53720751 0.53738627 ... 0.55560124 0.55644138 0.55781778]
#    243)  gruppo_0/ZsRr9AmAoTSaIFq.wav  / label: 1 / freq: 16.0kHz / dim.: 64000 / data: [0.53960281 0.53515185 0.53039701 ... 0.54800422 0.57512111 0.59796579]
#    244)  gruppo_0/SIZY0AuttCmnIqY.wav  / label: 1 / freq: 16.0kHz / dim.: 64000 / data: [0.50537154 0.49829291 0.47866578 ... 0.48551204 0.48706719 0.48265199]
#    245)  gruppo_0/owVZYMxynPganem.wav  / label: 1 / freq: 16.0kHz / dim.: 64000 / data: [0.57664051 0.56872173 0.56042758 ... 0.53808341 0.53702876 0.53731477]
#    246)  gruppo_0/LgbdiRT3Wyw4mCz.wav  / label: 1 / freq: 16.0kHz / dim.: 64000 / data: [0.54530504 0.5377259  0.53064727 ... 0.53987094 0.53438321 0.53522335]
#    247)  gruppo_0/N33nB5JXbY9zSEp.wav  / label: 1 / freq: 16.0kHz / dim.: 64000 / data: [0.56058846 0.56502154 0.56950825 ... 0.53370395 0.53375757 0.53354307]
#    248)  gruppo_0/ZGmnotOoDBUzzHM.wav  / label: 1 / freq: 16.0kHz / dim.: 64000 / data: [0.53431171 0.53434746 0.53434746 ... 0.53683213 0.53883417 0.53922743]
#    249)  gruppo_0/GkoxQGNSYTm3f5B.wav  / label: 1 / freq: 16.0kHz / dim.: 64000 / data: [0.53409721 0.53802978 0.54160485 ... 0.53631375 0.53154103 0.51745527]
#    250)  gruppo_0/U3ZTUXhUEAZDh4Y.wav  / label: 1 / freq: 16.0kHz / dim.: 64000 / data: [0.58523855 0.56596893 0.56738108 ... 0.57388771 0.56409202 0.55427846]
#    251)  gruppo_0/cdDZEZZcBKfQk7t.wav  / label: 1 / freq: 16.0kHz / dim.: 64000 / data: [0.53415083 0.53416871 0.53416871 ... 0.52880611 0.54526929 0.52798384]
#    252)  gruppo_0/Mh19mPYn9TdUXsk.wav  / label: 1 / freq: 16.0kHz / dim.: 64000 / data: [0.53155891 0.53002163 0.53043276 ... 0.53363245 0.53372182 0.53550936]
#    253)  gruppo_0/LnT35Ds4uLl7lvx.wav  / label: 1 / freq: 16.0kHz / dim.: 64000 / data: [0.57980444 0.58278963 0.57578249 ... 0.43158215 0.45224604 0.52240674]
#    254)  gruppo_0/CSWUTvliqM8bYsV.wav  / label: 1 / freq: 16.0kHz / dim.: 64000 / data: [0.50245786 0.51177091 0.50889298 ... 0.549613   0.5510609  0.55386733]
#    255)  gruppo_0/umAC2YdlChVchf0.wav  / label: 1 / freq: 16.0kHz / dim.: 64000 / data: [0.5217811  0.51706201 0.51942155 ... 0.53722539 0.54096134 0.54484028]
#    256)  gruppo_0/MGvN61wpic3sTNa.wav  / label: 1 / freq: 16.0kHz / dim.: 64000 / data: [0.57041989 0.56739896 0.56436015 ... 0.55556549 0.55286631 0.55168654]
#    257)  gruppo_0/7EecIZbwcmjS5x1.wav  / label: 1 / freq: 16.0kHz / dim.: 64000 / data: [0.50608655 0.50476378 0.50560392 ... 0.57365533 0.58284325 0.58441628]
#    258)  gruppo_0/iDO4MIytwn0Ik37.wav  / label: 1 / freq: 16.0kHz / dim.: 64000 / data: [0.55309869 0.5549041  0.54943425 ... 0.49042776 0.46790483 0.44983287]
#    259)  gruppo_0/C6HtI0lw4e9nwYA.wav  / label: 1 / freq: 16.0kHz / dim.: 64000 / data: [0.53361457 0.53434746 0.53491947 ... 0.53461559 0.53499097 0.53529485]
#    260)  gruppo_0/Sx0zujvT61jbl5Y.wav  / label: 1 / freq: 16.0kHz / dim.: 64000 / data: [0.53466922 0.53468709 0.53466922 ... 0.53386483 0.5337397  0.5338827 ]
#    261)  gruppo_0/EbCYky4pWcck6ca.wav  / label: 1 / freq: 16.0kHz / dim.: 64000 / data: [0.5640384  0.55368858 0.55885455 ... 0.57780241 0.57567524 0.57801691]
#    262)  gruppo_0/uumRfloXuGsdIWi.wav  / label: 1 / freq: 16.0kHz / dim.: 64000 / data: [0.59176304 0.59371146 0.59501636 ... 0.51609674 0.51813453 0.50109933]
#    263)  gruppo_0/3PhFMR0W8DAnhmz.wav  / label: 1 / freq: 16.0kHz / dim.: 64000 / data: [0.57342295 0.58248574 0.57790966 ... 0.5311299  0.53320344 0.53749352]
#    264)  gruppo_0/sAzHtun0mB0ltfG.wav  / label: 1 / freq: 16.0kHz / dim.: 64000 / data: [0.54510841 0.53845879 0.53361457 ... 0.57025901 0.56130347 0.5520798 ]
#    265)  gruppo_0/uGjCGSUAyyn1l9H.wav  / label: 1 / freq: 16.0kHz / dim.: 64000 / data: [0.53729689 0.543017   0.54650269 ... 0.58323651 0.58289688 0.57386983]
#    266)  gruppo_0/rQbQ32SV25zkesb.wav  / label: 1 / freq: 16.0kHz / dim.: 64000 / data: [0.53683213 0.54080046 0.54441128 ... 0.57336932 0.56434228 0.55847917]
#    267)  gruppo_0/AJET6VI6cSG5Xgw.wav  / label: 1 / freq: 16.0kHz / dim.: 64000 / data: [0.53411508 0.53411508 0.53409721 ... 0.56082084 0.54523354 0.52821622]
#    268)  gruppo_0/QUJawDU8X1IMYgP.wav  / label: 1 / freq: 16.0kHz / dim.: 64000 / data: [0.48250898 0.47378582 0.46256011 ... 0.55906905 0.55127541 0.54507266]
#    269)  gruppo_0/3xiTXNQkIQUgqUv.wav  / label: 1 / freq: 16.0kHz / dim.: 64000 / data: [0.40696781 0.43576498 0.47181953 ... 0.56688057 0.57269006 0.56857873]
#    270)  gruppo_0/xZGmRp66q5adVrG.wav  / label: 1 / freq: 16.0kHz / dim.: 64000 / data: [0.47941655 0.48983787 0.50487103 ... 0.53611712 0.53391845 0.53561661]
#    271)  gruppo_0/mFQdfXDU3SGhdPt.wav  / label: 1 / freq: 16.0kHz / dim.: 64000 / data: [0.53593837 0.54090771 0.54133672 ... 0.48225873 0.47764689 0.4727133 ]
#    272)  gruppo_0/8ycJqspnOKNT4O1.wav  / label: 1 / freq: 16.0kHz / dim.: 64000 / data: [0.52767996 0.53114778 0.53354307 ... 0.54053233 0.54459003 0.54230199]
#    273)  gruppo_0/8BxBbiNc3rhrfMD.wav  / label: 1 / freq: 16.0kHz / dim.: 64000 / data: [0.59240656 0.59932431 0.59090503 ... 0.53811916 0.53443684 0.5310584 ]
#    274)  gruppo_0/EhDQTsQ8RoHTXBv.wav  / label: 1 / freq: 16.0kHz / dim.: 64000 / data: [0.45805552 0.50463865 0.51566773 ... 0.47948805 0.48849722 0.48923011]
#    275)  gruppo_0/4CA0CjLAaq6q9SG.wav  / label: 1 / freq: 16.0kHz / dim.: 64000 / data: [0.54056808 0.56300163 0.57728402 ... 0.56389539 0.55529736 0.5548326 ]
#    276)  gruppo_0/VA0dsEGKQtqGRYl.wav  / label: 1 / freq: 16.0kHz / dim.: 64000 / data: [0.52560642 0.53175554 0.54441128 ... 0.54537654 0.54358901 0.53942406]
#    277)  gruppo_0/iClkT1XEHER3qI7.wav  / label: 1 / freq: 16.0kHz / dim.: 64000 / data: [0.50765958 0.50512128 0.50483528 ... 0.55034589 0.54634181 0.5364925 ]
#    278)  gruppo_0/XetjQu9d65beJ75.wav  / label: 1 / freq: 16.0kHz / dim.: 64000 / data: [0.51218204 0.52737608 0.54003182 ... 0.55225855 0.55191892 0.55299144]
#    279)  gruppo_0/IrkBWkTuFwVOwxm.wav  / label: 1 / freq: 16.0kHz / dim.: 64000 / data: [0.52406914 0.516347   0.51750889 ... 0.51273618 0.51302218 0.51470247]
#    280)  gruppo_0/0duJkPW9XGTju30.wav  / label: 1 / freq: 16.0kHz / dim.: 64000 / data: [0.56965125 0.56904349 0.58039433 ... 0.57104553 0.56604043 0.56743471]
#    281)  gruppo_0/I0Sa8E8atx1Ee6L.wav  / label: 1 / freq: 16.0kHz / dim.: 64000 / data: [0.47603811 0.45344368 0.44221797 ... 0.53406146 0.5340257  0.5340257 ]
#    282)  gruppo_0/geB8JtaBmgt4eoF.wav  / label: 1 / freq: 16.0kHz / dim.: 64000 / data: [0.49936543 0.49927605 0.49700588 ... 0.53223817 0.53658188 0.53536636]
#    283)  gruppo_0/EJyQibjmSRTsHKW.wav  / label: 1 / freq: 16.0kHz / dim.: 64000 / data: [0.54857623 0.54012119 0.53736839 ... 0.45074451 0.44988649 0.45160252]
#    284)  gruppo_0/9cyX4HZlaVvI7uE.wav  / label: 1 / freq: 16.0kHz / dim.: 64000 / data: [0.53175554 0.53161253 0.53150528 ... 0.54471516 0.53915593 0.54862986]
#    285)  gruppo_0/EQJEnEQb6QLfwCA.wav  / label: 1 / freq: 16.0kHz / dim.: 64000 / data: [0.54190873 0.55014926 0.5654863  ... 0.55987344 0.5613571  0.55545823]
#    286)  gruppo_0/BBJL2xM23fZ8UEu.wav  / label: 1 / freq: 16.0kHz / dim.: 64000 / data: [0.52986075 0.53499097 0.52505229 ... 0.43043812 0.43326243 0.46188084]
#    287)  gruppo_0/0Tyb9YAKvR48Pnl.wav  / label: 1 / freq: 16.0kHz / dim.: 64000 / data: [0.5759255  0.57008026 0.56863236 ... 0.45841303 0.54755734 0.59133404]
#    288)  gruppo_0/AwIrJblauh41RtN.wav  / label: 1 / freq: 16.0kHz / dim.: 64000 / data: [0.56634431 0.5535992  0.53486585 ... 0.5176519  0.52589243 0.5310584 ]
#    289)  gruppo_0/8JXO1jCsVzrW0Np.wav  / label: 1 / freq: 16.0kHz / dim.: 64000 / data: [0.56863236 0.57660476 0.56595106 ... 0.55011351 0.56017732 0.56473553]
#    290)  gruppo_0/LSGzrddO2iZGXiB.wav  / label: 1 / freq: 16.0kHz / dim.: 64000 / data: [0.53390058 0.53409721 0.53406146 ... 0.53289956 0.53289956 0.53286381]
#    291)  gruppo_0/fqc4apo5Ho6u1BF.wav  / label: 1 / freq: 16.0kHz / dim.: 64000 / data: [0.57926818 0.57851742 0.57826716 ... 0.55860429 0.56105321 0.5616431 ]
#    292)  gruppo_0/CwBbNAgmvP7wLCx.wav  / label: 1 / freq: 16.0kHz / dim.: 64000 / data: [0.54160485 0.54557317 0.54805784 ... 0.53415083 0.53415083 0.53413296]
#    293)  gruppo_0/h86Se523aTbHbaa.wav  / label: 1 / freq: 16.0kHz / dim.: 64000 / data: [0.51239655 0.54369626 0.55068552 ... 0.53372182 0.5337397  0.53372182]
#    294)  gruppo_0/sh1st1jFpiwwg9V.wav  / label: 1 / freq: 16.0kHz / dim.: 64000 / data: [0.47319593 0.47746814 0.48249111 ... 0.56882899 0.58616806 0.59612463]
#    295)  gruppo_0/v4EuwbIgCyj5JTb.wav  / label: 1 / freq: 16.0kHz / dim.: 64000 / data: [0.53436534 0.53096902 0.52912786 ... 0.5377259  0.52532042 0.50537154]
#    296)  gruppo_0/7IxI0kz5U6266pa.wav  / label: 1 / freq: 16.0kHz / dim.: 64000 / data: [0.52741183 0.51223567 0.50226123 ... 0.52993225 0.53699301 0.54189085]
#    297)  gruppo_0/C7j4xzXq7ul0Dl2.wav  / label: 1 / freq: 16.0kHz / dim.: 64000 / data: [0.55013138 0.54105071 0.536278   ... 0.59262106 0.59533811 0.59235293]
#    298)  gruppo_0/Usl3zpwpXe9YD3g.wav  / label: 1 / freq: 16.0kHz / dim.: 64000 / data: [0.52841285 0.53150528 0.53424021 ... 0.46760095 0.48445739 0.49829291]
#    299)  gruppo_0/KnJmsdgATgTHfSt.wav  / label: 1 / freq: 16.0kHz / dim.: 64000 / data: [0.43356631 0.45921742 0.51345119 ... 0.59732227 0.58883149 0.57728402]
#    300)  gruppo_0/BCBo69rYQNWVM4D.wav  / label: 1 / freq: 16.0kHz / dim.: 64000 / data: [0.56861448 0.55340257 0.53953131 ... 0.53415083 0.53415083 0.53415083]
# ...
#    352)  gruppo_0/54gaJ4znXIauBfX.wav  / label: 2 / freq: 16.0kHz / dim.: 64000 / data: [0.45088751 0.4888011  0.53139803 ... 0.40473339 0.38807357 0.36807107]
#    353)  gruppo_0/ItBao3HJ27UQI9c.wav  / label: 2 / freq: 16.0kHz / dim.: 64000 / data: [0.40333911 0.38151333 0.41132939 ... 0.53415083 0.53415083 0.53415083]
#    354)  gruppo_0/VwtGrOlJStm9fqw.wav  / label: 2 / freq: 16.0kHz / dim.: 64000 / data: [0.53415083 0.53416871 0.53420446 ... 0.55063189 0.55728152 0.56654094]
#    355)  gruppo_0/lLzdBGpag0tUsnr.wav  / label: 2 / freq: 16.0kHz / dim.: 64000 / data: [0.66131598 0.65209231 0.63577213 ... 0.55075702 0.53894142 0.52347926]
#    356)  gruppo_0/7EZCwO1AxkorDID.wav  / label: 2 / freq: 16.0kHz / dim.: 64000 / data: [0.34488676 0.36362011 0.38625029 ... 0.64327977 0.6184688  0.58168135]
#    357)  gruppo_0/NtK6WL2P2fh8dMl.wav  / label: 2 / freq: 16.0kHz / dim.: 64000 / data: [0.32890621 0.35714924 0.40446526 ... 0.56133922 0.52174535 0.56341276]
#    358)  gruppo_0/doyJ8cOfRpS1ryT.wav  / label: 2 / freq: 16.0kHz / dim.: 64000 / data: [0.44627567 0.62363477 0.49300181 ... 0.4981499  0.49521835 0.49234042]
#    359)  gruppo_0/GJZm3J6iEzCv1NP.wav  / label: 2 / freq: 16.0kHz / dim.: 64000 / data: [0.4158161  0.40716444 0.3971185  ... 0.44750907 0.45317555 0.45837728]
#    360)  gruppo_0/uxdCVF8NqMgdecW.wav  / label: 2 / freq: 16.0kHz / dim.: 64000 / data: [0.58110934 0.57780241 0.57428096 ... 0.56696995 0.55586937 0.54534079]
#    361)  gruppo_0/ngYKeEFxme45ECD.wav  / label: 2 / freq: 16.0kHz / dim.: 64000 / data: [0.549756   0.54385714 0.54298125 ... 0.4609692  0.62955151 0.46386501]
#    362)  gruppo_0/dug7KR6h6TICngd.wav  / label: 2 / freq: 16.0kHz / dim.: 64000 / data: [0.25847738 0.2570831  0.26240995 ... 0.54006757 0.54015695 0.54029995]
#    363)  gruppo_0/k6Xy8cDIcOa1DKA.wav  / label: 2 / freq: 16.0kHz / dim.: 64000 / data: [0.24660815 0.29923315 0.35790001 ... 0.48504728 0.49739914 0.5309154 ]
#    364)  gruppo_0/fXB32qdPWEs2iNX.wav  / label: 2 / freq: 16.0kHz / dim.: 64000 / data: [0.53436534 0.55073915 0.56528967 ... 0.45335431 0.43926854 0.41576247]
#    365)  gruppo_0/yhEFdcViv7tECrK.wav  / label: 2 / freq: 16.0kHz / dim.: 64000 / data: [0.64242175 0.62901525 0.6307134  ... 0.54526929 0.54433977 0.51430921]
#    366)  gruppo_0/rHm1N06AQ3u9di7.wav  / label: 2 / freq: 16.0kHz / dim.: 64000 / data: [0.52566005 0.52553492 0.52528466 ... 0.56065996 0.55039951 0.53727902]
#    367)  gruppo_0/uPX5H7ZKzkrmlNd.wav  / label: 2 / freq: 16.0kHz / dim.: 64000 / data: [0.48964124 0.48681694 0.48370663 ... 0.53415083 0.53420446 0.53415083]
#    368)  gruppo_0/T8OolysnDXG2KbV.wav  / label: 2 / freq: 16.0kHz / dim.: 64003 / data: [0.53415083 0.53415083 0.53415083 ... 0.53415083 0.53415083 0.53415083]
#    369)  gruppo_0/F0qKkinY48ifX7k.wav  / label: 2 / freq: 16.0kHz / dim.: 64000 / data: [0.4002288  0.42797133 0.46575979 ... 0.52705432 0.5256243  0.52773359]
#    370)  gruppo_0/dur3gZH0Ehr6Jy4.wav  / label: 2 / freq: 16.0kHz / dim.: 64000 / data: [0.44291511 0.45364031 0.46983537 ... 0.47428633 0.46180934 0.45002949]
#    371)  gruppo_0/Om5bf6MvfITGy2F.wav  / label: 2 / freq: 16.0kHz / dim.: 64000 / data: [0.54290975 0.53743989 0.5378689  ... 0.57853529 0.59002914 0.61403571]
#    372)  gruppo_0/QXJ8ARZIkL1wXrm.wav  / label: 2 / freq: 16.0kHz / dim.: 64000 / data: [0.80054699 0.7922707  0.79327172 ... 0.57433459 0.57276156 0.57213592]
#    373)  gruppo_0/dmmxehA7ESxeAwc.wav  / label: 2 / freq: 16.0kHz / dim.: 64000 / data: [0.60250612 0.63461023 0.66387216 ... 0.53273868 0.53255993 0.53213092]
#    374)  gruppo_0/HGtbL2ZQTSgqLCK.wav  / label: 2 / freq: 16.0kHz / dim.: 64000 / data: [0.53424021 0.53404358 0.53416871 ... 0.60742184 0.42123233 0.67842268]
#    375)  gruppo_0/b9DzWDw2w4ql5lw.wav  / label: 2 / freq: 16.0kHz / dim.: 64000 / data: [0.66859124 0.65901006 0.65287882 ... 0.38762669 0.38069106 0.37545359]
#    376)  gruppo_0/OxCbg3j95TF09yq.wav  / label: 2 / freq: 16.0kHz / dim.: 64000 / data: [0.57676564 0.59090503 0.60731459 ... 0.42909747 0.43152852 0.43304792]
#    377)  gruppo_0/ab5EiOItXworZ0K.wav  / label: 2 / freq: 16.0kHz / dim.: 64000 / data: [0.53804766 0.52682194 0.55218705 ... 0.56673757 0.56820335 0.57798116]
#    378)  gruppo_0/NXFJZMAigsjkK5f.wav  / label: 2 / freq: 16.0kHz / dim.: 64000 / data: [0.35729224 0.36757056 0.3816742  ... 0.61610925 0.61512611 0.61171192]
#    379)  gruppo_0/Z1W5Xnfs3Xy1enj.wav  / label: 2 / freq: 16.0kHz / dim.: 64000 / data: [0.50016982 0.49568311 0.5178664  ... 0.63012352 0.6411526  0.65123429]
#    380)  gruppo_0/A3AkyboTWc0ZdCR.wav  / label: 2 / freq: 16.0kHz / dim.: 64000 / data: [0.54072896 0.48265199 0.43839265 ... 0.55420696 0.5482366  0.54072896]
#    381)  gruppo_0/TexBfx5GIWkDmld.wav  / label: 2 / freq: 16.0kHz / dim.: 64000 / data: [0.44795596 0.49334144 0.54737858 ... 0.53611712 0.53901292 0.53933468]
#    382)  gruppo_0/HwXuo9uzZbE4q1C.wav  / label: 2 / freq: 16.0kHz / dim.: 64000 / data: [0.49105339 0.49246555 0.49371682 ... 0.41803264 0.41876553 0.42169708]
#    383)  gruppo_0/QhwsPNnXbx309LS.wav  / label: 2 / freq: 16.0kHz / dim.: 64000 / data: [0.58223549 0.5061223  0.44454177 ... 0.52662532 0.53509822 0.54666357]
#    384)  gruppo_0/be1lNgLMpMtFty8.wav  / label: 2 / freq: 16.0kHz / dim.: 64000 / data: [0.57821354 0.60223799 0.61130079 ... 0.62195449 0.62170423 0.61913019]
#    385)  gruppo_0/cj1C3XuFHnLTnx2.wav  / label: 2 / freq: 16.0kHz / dim.: 64000 / data: [0.49200079 0.48724595 0.47888029 ... 0.57050927 0.52508804 0.48654881]
#    386)  gruppo_0/p8ifVwRfGaSt3w7.wav  / label: 2 / freq: 16.0kHz / dim.: 64000 / data: [0.55184742 0.52153084 0.49947268 ... 0.5441789  0.53726114 0.5259818 ]
#    387)  gruppo_0/ryQxmwsNArB207B.wav  / label: 2 / freq: 16.0kHz / dim.: 64000 / data: [0.69313408 0.67617039 0.66129811 ... 0.37938616 0.35756037 0.38986111]
#    388)  gruppo_0/0uA3NRp72lv5ael.wav  / label: 2 / freq: 16.0kHz / dim.: 64000 / data: [0.53404358 0.53415083 0.53422233 ... 0.51935005 0.47948805 0.45642887]
#    389)  gruppo_0/WkKP7LhG9el8E9h.wav  / label: 2 / freq: 16.0kHz / dim.: 64000 / data: [0.68938026 0.67722503 0.67280982 ... 0.24755555 0.25567095 0.29022398]
#    390)  gruppo_0/hWuf1dWOnCS46xa.wav  / label: 2 / freq: 16.0kHz / dim.: 64000 / data: [0.54771821 0.54807572 0.54800422 ... 0.56239387 0.56523604 0.56786372]
#    391)  gruppo_0/6QUn1z9MBYpUJWf.wav  / label: 2 / freq: 16.0kHz / dim.: 64000 / data: [0.64027671 0.63292995 0.62240137 ... 0.37550721 0.37338005 0.36894696]
#    392)  gruppo_0/RN3Cy1GG2pTakMZ.wav  / label: 2 / freq: 16.0kHz / dim.: 64000 / data: [0.58076971 0.58255725 0.58850973 ... 0.36683767 0.35096437 0.3405073 ]
#    393)  gruppo_0/xaSpA7ns7EKqyhb.wav  / label: 2 / freq: 16.0kHz / dim.: 64000 / data: [0.60777935 0.62038146 0.6276031  ... 0.53424021 0.53407933 0.53416871]
#    394)  gruppo_0/lrd2v8unF1AKb5c.wav  / label: 2 / freq: 16.0kHz / dim.: 64000 / data: [0.5351161  0.53522335 0.53543786 ... 0.51128828 0.52678619 0.54253437]
#    395)  gruppo_0/kExHUhqbe8NQjgp.wav  / label: 2 / freq: 16.0kHz / dim.: 64000 / data: [0.48497578 0.46819084 0.45081601 ... 0.49915092 0.4580734  0.42629105]
#    396)  gruppo_0/cnuV23WfRAiTZAp.wav  / label: 2 / freq: 16.0kHz / dim.: 64000 / data: [0.53804766 0.53763652 0.53726114 ... 0.56925799 0.57826716 0.58725846]
#    397)  gruppo_0/jT8Mc6wPL6slEOE.wav  / label: 2 / freq: 16.0kHz / dim.: 64000 / data: [0.67699265 0.6676081  0.6570974  ... 0.65114492 0.65345083 0.64935738]
#    398)  gruppo_0/EnDWdkeQtVPkPYM.wav  / label: 2 / freq: 16.0kHz / dim.: 63999 / data: [0.53415083 0.53415083 0.53415083 ... 0.53415083 0.53415083 0.53415083]
#    399)  gruppo_0/BuLLIJi8Z7dN0Ss.wav  / label: 2 / freq: 16.0kHz / dim.: 64000 / data: [0.36656954 0.38498114 0.40918435 ... 0.60827986 0.55944443 0.50640831]
#    400)  gruppo_0/5MYNSoj2X616NsO.wav  / label: 2 / freq: 16.0kHz / dim.: 64000 / data: [0.67175518 0.66128023 0.66483742 ... 0.4158876  0.40966698 0.40396475]
#    401)  gruppo_0/FiqcB0YtwATA3vQ.wav  / label: 2 / freq: 16.0kHz / dim.: 64000 / data: [0.41022112 0.41815777 0.43326243 ... 0.52698282 0.52473053 0.52558855]
#    402)  gruppo_0/Q43fZDv2DlFBU0h.wav  / label: 2 / freq: 16.0kHz / dim.: 64000 / data: [0.63725578 0.64996514 0.6676081  ... 0.5377974  0.53745777 0.53726114]
#    403)  gruppo_0/8e1OVhtnn4vd7kV.wav  / label: 2 / freq: 16.0kHz / dim.: 64000 / data: [0.69556513 0.69170406 0.68696709 ... 0.53143378 0.53136228 0.53136228]
#    404)  gruppo_0/VFjpOMIAQ0j8o45.wav  / label: 2 / freq: 16.0kHz / dim.: 64000 / data: [0.53409721 0.53413296 0.53415083 ... 0.64285076 0.64433441 0.64649733]
#    405)  gruppo_0/HvXPB1VY2boInxV.wav  / label: 2 / freq: 16.0kHz / dim.: 64000 / data: [0.72178825 0.71556763 0.69989096 ... 0.52952112 0.52682194 0.53729689]
#    406)  gruppo_0/f5fGzsvGKukk3fp.wav  / label: 2 / freq: 16.0kHz / dim.: 64000 / data: [0.51323669 0.51493484 0.52925299 ... 0.53209517 0.53164828 0.5322203 ]
#    407)  gruppo_0/2THYbWFYUx1KBZ3.wav  / label: 2 / freq: 16.0kHz / dim.: 64000 / data: [0.54103284 0.52921724 0.52717945 ... 0.52928874 0.52918149 0.52905636]
#    408)  gruppo_0/B5wTz44veecTC5Q.wav  / label: 2 / freq: 16.0kHz / dim.: 64000 / data: [0.76293728 0.74105786 0.70879288 ... 0.51434496 0.50349463 0.49128577]
#    409)  gruppo_0/1ArVjjje1nZtfEs.wav  / label: 2 / freq: 16.0kHz / dim.: 64000 / data: [0.52253186 0.53626012 0.54303487 ... 0.57900005 0.57989382 0.58186011]
#    410)  gruppo_0/bIOAtOuilKfPcbR.wav  / label: 2 / freq: 16.0kHz / dim.: 64000 / data: [0.5337397  0.53361457 0.53338219 ... 0.54398227 0.54378564 0.54382139]
#    411)  gruppo_0/IjAFSzzZb2kgsYE.wav  / label: 2 / freq: 16.0kHz / dim.: 64000 / data: [0.53415083 0.53416871 0.53416871 ... 0.64034821 0.64016946 0.63780991]
#    412)  gruppo_0/Vic6KACktkRF8CB.wav  / label: 2 / freq: 16.0kHz / dim.: 64000 / data: [0.65511324 0.64567506 0.63228643 ... 0.6607976  0.649268   0.63929357]
#    413)  gruppo_0/3L5dJzOiH2bjamY.wav  / label: 2 / freq: 16.0kHz / dim.: 64000 / data: [0.56486066 0.59855567 0.62132885 ... 0.59646426 0.58545305 0.57774878]
#    414)  gruppo_0/jeP3AS02u8FYmou.wav  / label: 2 / freq: 16.0kHz / dim.: 64000 / data: [0.542874   0.55011351 0.55767478 ... 0.53407933 0.53409721 0.53407933]
#    415)  gruppo_0/azD1YVCxv2dyilZ.wav  / label: 2 / freq: 16.0kHz / dim.: 64000 / data: [0.53483009 0.52832347 0.52169172 ... 0.5338112  0.53386483 0.53382908]
#    416)  gruppo_0/jK10aJOHzV8kULm.wav  / label: 2 / freq: 16.0kHz / dim.: 64000 / data: [0.50549667 0.49298393 0.47462596 ... 0.53422233 0.53407933 0.53413296]
#    417)  gruppo_0/maDWvWgr8xo8AOD.wav  / label: 2 / freq: 16.0kHz / dim.: 64000 / data: [0.509894   0.5390308  0.50869635 ... 0.51752677 0.5591763  0.50201098]
#    418)  gruppo_0/Hyz81QlFe3DALni.wav  / label: 2 / freq: 16.0kHz / dim.: 64000 / data: [0.68666321 0.70977602 0.73199507 ... 0.57731977 0.58827735 0.59848417]
#    419)  gruppo_0/JW0gu3QR9TIbshY.wav  / label: 2 / freq: 16.0kHz / dim.: 64000 / data: [0.53415083 0.53415083 0.53422233 ... 0.53422233 0.53420446 0.53416871]
#    420)  gruppo_0/atjdJXobBt3K2iO.wav  / label: 2 / freq: 16.0kHz / dim.: 64000 / data: [0.34116869 0.3496416  0.37177127 ... 0.60456179 0.58901024 0.56865023]
#    421)  gruppo_0/tottrocohZTPSle.wav  / label: 2 / freq: 16.0kHz / dim.: 64000 / data: [0.53409721 0.53415083 0.53422233 ... 0.55179379 0.53731477 0.5193143 ]
#    422)  gruppo_0/TZBTMdPT2oBR5ue.wav  / label: 2 / freq: 16.0kHz / dim.: 64000 / data: [0.5339542  0.53400783 0.53354307 ... 0.58638257 0.58745509 0.58641832]
#    423)  gruppo_0/kLH4ruqgDu79no1.wav  / label: 2 / freq: 16.0kHz / dim.: 64000 / data: [0.65554225 0.66569544 0.67474036 ... 0.53416871 0.53416871 0.53413296]
#    424)  gruppo_0/xpicv7koAOeiQvk.wav  / label: 2 / freq: 16.0kHz / dim.: 64000 / data: [0.43646211 0.44166384 0.45083388 ... 0.6743471  0.69590476 0.71047316]
#    425)  gruppo_0/9FlCxM2yBxJSJAm.wav  / label: 2 / freq: 16.0kHz / dim.: 63993 / data: [0.53415083 0.53415083 0.53415083 ... 0.53415083 0.53415083 0.53415083]
#    426)  gruppo_0/kpW2usqxK7Gr8Zu.wav  / label: 2 / freq: 16.0kHz / dim.: 64000 / data: [0.52884186 0.52885973 0.52902061 ... 0.50345888 0.59982482 0.47625261]
#    427)  gruppo_0/8uIebWFba8jOkpp.wav  / label: 2 / freq: 16.0kHz / dim.: 64000 / data: [0.56768497 0.51121677 0.5657008  ... 0.56092809 0.58652557 0.62170423]
#    428)  gruppo_0/23v9IEQupDjLxlO.wav  / label: 2 / freq: 16.0kHz / dim.: 64000 / data: [0.52725095 0.52537404 0.52458753 ... 0.45011887 0.47850491 0.48944461]
#    429)  gruppo_0/He2OB4MumO8H9Qd.wav  / label: 2 / freq: 16.0kHz / dim.: 64000 / data: [0.49936543 0.48971274 0.49062439 ... 0.53416871 0.53424021 0.53413296]
#    430)  gruppo_0/lYntObqu04fmOUJ.wav  / label: 2 / freq: 16.0kHz / dim.: 64000 / data: [0.57224318 0.58840248 0.60366802 ... 0.59481973 0.59562412 0.59279981]
#    431)  gruppo_0/wUshvpVQ1bqJlxm.wav  / label: 2 / freq: 16.0kHz / dim.: 64000 / data: [0.73687503 0.74470443 0.74913751 ... 0.51883167 0.52371164 0.52877036]
#    432)  gruppo_0/twFRVruiojrpXSN.wav  / label: 2 / freq: 16.0kHz / dim.: 64000 / data: [0.63132117 0.65096616 0.66800136 ... 0.31179951 0.30631178 0.29962641]
#    433)  gruppo_0/LLbPKSieTqZ0EcZ.wav  / label: 2 / freq: 16.0kHz / dim.: 64000 / data: [0.53420446 0.53413296 0.53413296 ... 0.52834135 0.54389289 0.52632143]
#    434)  gruppo_0/pGcA4B9lS7RQj99.wav  / label: 2 / freq: 16.0kHz / dim.: 64000 / data: [0.46683231 0.46393651 0.46402588 ... 0.53465134 0.53390058 0.53107627]
#    435)  gruppo_0/qEQqisnRpeb4dil.wav  / label: 2 / freq: 16.0kHz / dim.: 63999 / data: [0.53415083 0.53415083 0.53415083 ... 0.53415083 0.53415083 0.53415083]
#    436)  gruppo_0/gN8pWcPYyBOlq9l.wav  / label: 2 / freq: 16.0kHz / dim.: 64000 / data: [0.59884168 0.59294282 0.58863486 ... 0.53820853 0.53840516 0.53845879]
#    437)  gruppo_0/hGtPnSVfVxRDiVh.wav  / label: 2 / freq: 16.0kHz / dim.: 64000 / data: [0.51189604 0.51030513 0.50944712 ... 0.53406146 0.53407933 0.53420446]
#    438)  gruppo_0/aXudV6YZrN7qgNI.wav  / label: 2 / freq: 16.0kHz / dim.: 64000 / data: [0.53409721 0.53407933 0.53416871 ... 0.61099691 0.62495755 0.64015158]
#    439)  gruppo_0/mkfUASfjimzPao1.wav  / label: 2 / freq: 16.0kHz / dim.: 64000 / data: [0.57302969 0.54489391 0.52169172 ... 0.48426077 0.47700338 0.46536653]
#    440)  gruppo_0/XuUCInuz2Ctl0r7.wav  / label: 2 / freq: 16.0kHz / dim.: 64000 / data: [0.53947768 0.49437821 0.56259049 ... 0.56489641 0.55467172 0.54498329]
#    441)  gruppo_0/rqqCSedTAo1ffnS.wav  / label: 2 / freq: 16.0kHz / dim.: 64000 / data: [0.40650305 0.42884722 0.4476342  ... 0.65218168 0.65255707 0.65119854]
#    442)  gruppo_0/9GQtL8cwEOYwmJW.wav  / label: 2 / freq: 16.0kHz / dim.: 64000 / data: [0.53273868 0.52415852 0.51834903 ... 0.64724809 0.63786354 0.62810361]
#    443)  gruppo_0/HFYdtQzudrXZALz.wav  / label: 2 / freq: 16.0kHz / dim.: 64000 / data: [0.50310137 0.5007597  0.49970506 ... 0.57267218 0.57179629 0.57065227]
#    444)  gruppo_0/RJ15Vs0i4sQhgh6.wav  / label: 2 / freq: 16.0kHz / dim.: 64000 / data: [0.57571099 0.57059865 0.57124216 ... 0.50249361 0.50204673 0.50008044]
#    445)  gruppo_0/BCsi895QEpOKvfa.wav  / label: 2 / freq: 16.0kHz / dim.: 64000 / data: [0.53415083 0.53415083 0.53415083 ... 0.53415083 0.53415083 0.53415083]
#    446)  gruppo_0/OFd6Iai2loioaRX.wav  / label: 2 / freq: 16.0kHz / dim.: 64000 / data: [0.53413296 0.53413296 0.53416871 ... 0.59380083 0.57442397 0.5591763 ]
#    447)  gruppo_0/jUVLYWinwsf5M3c.wav  / label: 2 / freq: 16.0kHz / dim.: 64000 / data: [0.5258388  0.53459772 0.53799403 ... 0.49371682 0.50465653 0.51001913]
#    448)  gruppo_0/NmcjrHPAxRRbAIn.wav  / label: 2 / freq: 16.0kHz / dim.: 64000 / data: [0.55465384 0.56553992 0.57197505 ... 0.4000143  0.3960996  0.40169458]
#    449)  gruppo_0/MmaIO2LU2nQZbz4.wav  / label: 2 / freq: 16.0kHz / dim.: 64000 / data: [0.2912965  0.29074236 0.29090324 ... 0.46938848 0.44041256 0.41839015]
#    450)  gruppo_0/aN6jiGzpSiZNqfK.wav  / label: 2 / freq: 16.0kHz / dim.: 64000 / data: [0.53422233 0.53415083 0.53406146 ... 0.43765976 0.45360456 0.47310655]
#
# numero di file contenuti nel dataset: 450

# %% [markdown]
# ### Rimozione tracce fuori shape

# %%
lenght = 64000  # numero di dati per singolo file audio

# indici dei file audio che hanno la lunghezza scelta
index_keep = [index for index, array in enumerate(audio_norm) if len(array) == lenght]

print(f'tracce di dimensione =/= {lenght}: {[index for index, audio_norm[index] in enumerate(audio_norm) if len(audio_norm[index])!=lenght]}')
print(f'numero di file di dim. {lenght}: {len(index_keep)}')

# si filtrano i file audio e le labels
audio_norm = np.array([audio_norm[index] for index in index_keep])
paths = np.array([paths[index] for index in index_keep])
labels = np.array([labels[index] for index in index_keep])
# Out:
# tracce di dimensione =/= 64000: [318, 367, 397, 424, 434]
# numero di file di dim. 64000: 445

# %% [markdown]
# ### Plot di una traccia casuale

# %%
import matplotlib.pyplot as plt

# Definizionedella funzione che verrà utilizzata per plottare tutte le tracce, con ricostruzioni o senza, con zoom o senza
def plot_audio(audio, audio_rec, i, sr, reconstruction_plot, zoom):
    # Adattamento array
    if zoom:
      t = np.arange(zoom[0], zoom[1], 1)/sr  # tempi di campionamento
      audio = audio[i][zoom[0]:zoom[1]]
      l = 0.5
      if reconstruction_plot:
        audio_rec = audio_rec[i][zoom[0]:zoom[1]]
        l1 = 0.4
    else:
      t = np.arange(0, len(audio[i]), 1)/sr  # tempi di campionamento
      audio = audio[i]
      l = 0.15
      if reconstruction_plot:
        audio_rec = audio_rec[i]
        l1 = 0.1
    # Plot
    plt.figure(figsize = (12,4))
    delta = max(audio)-min(audio)
    plt.ylim(min(audio)-delta/20,max(audio)+delta/20)
    plt.axhline(y=min(audio), color='k', linestyle='--', linewidth=1)
    plt.axhline(y=max(audio), color='k', linestyle='--', linewidth=1)
    plt.plot(t, audio, linestyle='-', linewidth=l, color='b', label='Traccia audio originale') # plot traccia
    if reconstruction_plot: # vengono mostrati contemporaneamente i dati e la loro ricostruzione
        plt.plot(t, audio_rec, linestyle='-', linewidth= l1, color='red', label='Traccia audio ricostruita tramite AE')
        plt.legend(loc='best',fontsize=9)
    plt.title(f'Traccia n. {i+1}')
    plt.xlabel('t (s)')
    plt.ylabel('Ampiezza normalizzata')
    plt.grid()
    plt.show()

# %% [markdown]
# Per poter plottare una traccia zoommata, bata inserire in input, nel parametro **zoom** della funzione **plot_random_audio**, una lista del tipo: [inizio,fine], del range che si vuole visualizzare, in caso successivamente nel notebook si voglia andare a vedere nello specifico dei punti della ricostruzione confrontata con la traccia originale per poter valutare più accuratamente le performance di ricostruzione del modello.

# %%
import random
r = random.randint(0, n_paths-1)

# %%
plot_audio(audio=audio_norm, audio_rec=False, i=r, sr=sample_rate, reconstruction_plot=False, zoom=False)

# %%
# Esempio:
plot_audio(audio=audio_norm, audio_rec=False, i=r, sr=sample_rate, reconstruction_plot=False, zoom=[2500,3000])

# %% [markdown]
# # **AutoEncoder Convoluzionale**

# %% [markdown]
# ### **Preparazione dataset per training e validation**

# %%
# Importazione librerie e moduli di PyTorch
import torch
import torch.optim as optim
import torch.nn.functional as F
import torch.nn.init as init

from torch import nn
from torch.utils.data import Dataset
from torch.utils.data import TensorDataset, DataLoader, random_split
from torch.optim.lr_scheduler import ReduceLROnPlateau
from torchsummary import summary

import time # per poter misurare il tempo durante il training del modello

import warnings
warnings.filterwarnings('ignore') # filtro per omettere il print dei warning delle varie librerie

# %% [markdown]
# #### Riduzione della dimensione dei campioni ed estrazione frammenti casuali delle tracce

# %%
# Funzione che estrae un frammento (casuale o non) della dimensione desiderata da ciascuna traccia
def cutter(dataset, n, rand):
  if rand: # i frammenti vengono estrapolati in punti diversi del file
    trimmed_data = []
    for row in dataset:
      a = random.randint(0, lenght - n)
      trimmed_data.append(row[a:a+n])
  else:    # i frammenti vengono raccolti tutti nello stesso punto
      a = random.randint(0, lenght - n)
      trimmed_data = [row[a:a+n] for row in dataset]
  return trimmed_data

# %%
# DIMENSIONE DEL CAMPIONE DA TAGLIARE
#----------------------------------------------------------------------------------------------
n_trim = 4800
#----------------------------------------------------------------------------------------------

t_sample_trim = np.arange(0, n_trim,1)/sample_rate

# "taglio" del dataset a shape (445, n_trim)
audio_cut = np.array(cutter(audio_norm, n_trim, rand=False))
print(f'dataset shape: {audio_cut.shape}')
# Out:
# dataset shape: (445, 4800)

# %% [markdown]
# #### Creazione dataset train/validation

# %%
batch_n = 1                                              # IMPOSTAZIONE DELLA DIMENSIONE DEL BATCH

labels = labels.reshape((-1, 1))                         # rimodella le etichette in un array 2D con forma (numero di labels, 1)
labels = torch.Tensor(labels).int()                      # converte l'array 'labels' in un tensore Torch di interi

audio_cut = torch.Tensor(audio_cut).float()              # converte i dati audio in un tensore Torch a 32-bit floating point

dataset_audio = TensorDataset(audio_cut,labels)          # creazione TensorDataset a partire dal tensore audio

# creazione dei dataset per training e validation
dataset_train, dataset_val = random_split(dataset_audio,                                                    # divisione dataset audio in due parti:
                                          [int(0.8*(len(dataset_audio))), int(0.2*(len(dataset_audio)))])   # 80% training set / 20% validation set
# creazione DataLoader generale
audio_dl = DataLoader(dataset_audio, batch_size=batch_n, shuffle=False, num_workers=1, drop_last=True)

# creazione DataLoader per il training set
audio_dl_train = DataLoader(dataset_train, batch_size=batch_n, shuffle=False, num_workers=1, drop_last=True)

# creazione DataLoader per il validation set
audio_dl_val = DataLoader(dataset_val, batch_size=batch_n, shuffle=False, num_workers=1, drop_last=True)

audio_b_train, label_train = next(iter(audio_dl_train))   # estrazione primo batch dal DataLoader di training
audio_b_train = audio_b_train.reshape(audio_b_train.shape[0], 1, audio_b_train.shape[1]) # definizione forma del tensore per avere canali  alla 2a componente

audio_b_val, label_val = next(iter(audio_dl_val))         # estrazione primo batch dal DataLoader di validation
audio_b_val = audio_b_val.reshape(audio_b_val.shape[0], 1, audio_b_val.shape[1]) # definizione forma del tensore per avere i canali alla seconda componente

# check delle dimensioni dei tensori di training e validation
print(f'training   : {audio_b_train.shape}')
print(f'validation : {audio_b_val.shape}')
# Out:
# training   : torch.Size([1, 1, 4800])
# validation : torch.Size([1, 1, 4800])

# %% [markdown]
# ### **Implementazione AE e training del modello**

# %% [markdown]
#  #### Definizione della classe per l'AutoEncoder convoluzionale (1d)

# %%
class AutoEncoder(nn.Module):

    def __init__(self, encoder_size, decoder_size, latent_dim, kernel_size, stride, padding, dropout):
        super(AutoEncoder, self).__init__()
        self.encoder_size = encoder_size            # dim. dei layer dell'encoder
        self.decoder_size = decoder_size            # dim. dei layer del decoder
        self.latent_dim = latent_dim                # dim. dello spazio latente
        layers1 = []                                # layers dell'encoder
        layers2 = []                                # layers del decoder

    # Encoder ------------------------------------------------------------------------------------------------------------------------------------------------

        # layers di convoluzione, il primo in_channels è 1 (un solo canale essendo file audio)
        for i in range(len(self.encoder_size)):
            if i==0:  # primo layer
                layers1.append(nn.Conv1d(in_channels=1, out_channels=self.encoder_size[i],
                                         kernel_size=kernel_size[i], stride=stride[i], padding=padding[i]))
            else:     # layer successivo, in_channels è l'out_channels del layer precedente
                layers1.append(nn.Conv1d(in_channels=self.encoder_size[i - 1], out_channels=self.encoder_size[i],
                                         kernel_size=kernel_size[i], stride=stride[i], padding=padding[i]))

            layers1.append(nn.ReLU())                               # funzione di attivazione ReLU

            if dropout: layers1.append(nn.Dropout(dropout))         # dropout per regolarizzazione

        self.Encoder = nn.Sequential(*layers1)                      # creazione encoder da sequenza dei layer

        # output dell'encoder per mappare allo spazio latente
        self.OutEncoder = nn.Conv1d(in_channels=self.encoder_size[-1], out_channels=self.latent_dim,
                                    kernel_size=kernel_size[-1], stride=stride[-1], padding=padding[-1])

    # Decoder ------------------------------------------------------------------------------------------------------------------------------------------------

        for i in range(len(self.decoder_size)):
            if i==0:  # primo layer convoluzione trasposta
                layers2.append(nn.ConvTranspose1d(in_channels=self.latent_dim, out_channels=self.decoder_size[i],
                                                  kernel_size=kernel_size[i], stride=stride[i], padding=padding[i]))
            else:     # layer successivo
                layers2.append(nn.ConvTranspose1d(in_channels=self.decoder_size[i - 1], out_channels=self.decoder_size[i],
                                                  kernel_size=kernel_size[i], stride=stride[i], padding=padding[i]))

            layers2.append(nn.ReLU())                               # funzione di attivazione ReLU

            if dropout: layers2.append(nn.Dropout(dropout))         # dropout per regolarizzazione

        self.Decoder = nn.Sequential(*layers2)                      # crazione decoder come sequenza dei layer

        # output del decoder per ricostruire l'input iniziale
        self.OutDecoder = nn.ConvTranspose1d(in_channels=self.decoder_size[-1], out_channels=1,
                                             kernel_size=kernel_size[-1], stride=stride[-1], padding=padding[-1])


    # Rappresentazione latente e ricostruzione ---------------------------------------------------------------------------------------------------------------

    def forward(self, x):
        x = self.Encoder(x)                           # manda l'input attraverso l'encoder
        z = self.OutEncoder(x)                        # viene mappato l'output dell'encoder nello spazio latente

        x = self.Decoder(z)                           # decodifica la rappresentazione latente per ricostruire l'input originale.
        x_rec = self.OutDecoder(x)                    # restituisce direttamente l'output del decoder

        return z, x_rec


    # Compilatore del modello : definizione della loss, opt e stampa del sommario ----------------------------------------------------------------------------

    def compile(self, lr, Scheduler, scheduler_params=None):
        global criterion
        global opt
        global scheduler

        if torch.cuda.is_available(): model.cuda()    # trasferimento del modello alla GPU se disponibile

        criterion = nn.SmoothL1Loss()
        opt = optim.Adam(model.parameters(), lr=lr)

        # Inizializzazione scheduler
        if Scheduler: scheduler = ReduceLROnPlateau(opt, **scheduler_params)
        else: scheduler = None

        # Generazione sommario dettagliato del modello (sia nel caso in cui si usa la GPU, sia quando si usa la CPU)
        if torch.cuda.is_available(): summary(model.cuda(), input_size=(1, audio_b_train.shape[2]))
        else: summary(model, input_size=(1, audio_b_train.shape[2]))


    # Salvataggio dei file audio ricostruiti -----------------------------------------------------------------------------------------------------------------

    def save(self, dir, audio_rec, lenght_vector, sr):
        audio_rec = audio_rec.detach().numpy()                       # i vettori vengono converiti in array numpy
        folder = f'/content/ReconstructedAudios_{dir}'              # costituzione nome cartella
        os.makedirs(folder, exist_ok=True)                           # creazione cartella

        for i in range(audio_rec.shape[0]):
            filename = f'{folder}/reconstructed_audio_{i+1:3d}.wav'  # creazione percorso del file
            write(filename, sr, audio_rec[i])                        # scrittura del file (percorso, frequenza, dati audio) in formato .wav
        print(f'Audio ricostruiti salvati in "{folder}"')


    # Allenamento del modello --------------------------------------------------------------------------------------------------------------------------------

    def fit(self, epochs):
        t_loss = []                                     # train loss
        v_loss = []                                     # validation loss
        folder = '/content/TrainingCheckpointers_Folder'
        os.makedirs(folder, exist_ok=True)              # creazione cartella per checkpointers di PyTorch

        for epoch in range(epochs):                     # ciclo per eseguire il training per il numero di epoche inserito
            t0 = time.time()                            # registrazione tempo di inizio dell'epoca

        # TRAINING

            model.train()                               # impostazione del modello in modalità di training
            train_loss = 0                              # inizializzazione loss del training
            counter = 0                                 # inizializzazione contatore per i batch

            for xb, _ in audio_dl_train:                # ciclo su tutti i batch del DataLoader di training
                if isinstance(xb, list):
                  xb = torch.stack(xb)                  # conversione in tensore Torch se il batch è una lista
                xb = xb.view(batch_n, 1, xb.shape[1])   # rimodella il tensor 'xb' per aggiungere la dimensione del canale
                if torch.cuda.is_available():           # muove l'input nella GPU se è disponibile
                    xb = xb.cuda()
                counter += 1                            # incremento contatore dei batch di training

                z, pred = model(xb)                     # applicazione del modello

                loss = criterion(pred, xb)              # CALCOLO DELLA LOSS TRA L'OUTPUT DEL MODELLO E L'INPUT
                train_loss += loss.item()               # incremento loss totale

                # backpropagation
                opt.zero_grad()                         # azzeramento dei gradienti accumulati
                loss.backward()                         # calcolo dei gradienti tramite backpropagation
                opt.step()                              # aggiornamento dei parametri del modello

            train_loss /= counter                       # calcolo della loss media per l'epoca
            t_loss.append(train_loss)

        # VALIDATION

            model.eval()                                # impostazione del modello in modalità di valutazione
            val_loss = 0                                # inizializzazione loss
            counter = 0                                 # inizializzazione contatore sui batch di validation

            with torch.no_grad():                       # disattivazione calcolo dei gradienti
                for xb, _ in audio_dl_val:              # ciclo sui batch del DataLoader di validation
                  if isinstance(xb, list): xb = torch.stack(xb)
                  xb = xb.view(batch_n, 1, xb.shape[1])
                  if torch.cuda.is_available(): xb = xb.cuda()
                  counter += 1                          # incremento contatore dei batch di validation

                  z, pred = model(xb)                   # applicazione del modello

                  loss = criterion(pred, xb)            # CALCOLO DELLA LOSS
                  val_loss += loss.item()               # incremento loss totale

            val_loss /= counter                         # loss media per l'epoca di validation
            v_loss.append(val_loss)

            if scheduler: scheduler.step(val_loss)      # aggiorna il learning rate in base alla validation loss

        # OUTPUT

            # salvataggio parametri del modello ogni 20 epoche
            if (epoch + 1) % 20 == 0: torch.save({'epoch': epoch+1, 'model_state_dict': model.state_dict(), 'optimizer_state_dict': opt.state_dict(),
                           'train_loss': train_loss,'val_loss': val_loss,}, f'{folder}/training_checkpoint{epoch:3d}.pth')

            elapsed_time = time.time() - t0             # tempo impiegato per l'esecuzione di un'epoca
            print(f"epoch: {epoch+1:4d} \t time(s): {elapsed_time:.4f} \t train loss: {train_loss:.8f} \t val loss: {val_loss:.8f}")

        return t_loss, v_loss


# Inizializzazione dei pesi della rete neurale con il metodo Xavier/Glorot -----------------------------------------------------------------------------------

def weights_init_glorot(m):
    if isinstance(m, nn.Conv1d) or isinstance(m, nn.ConvTranspose1d):
        init.xavier_uniform_(m.weight)
        if m.bias is not None: init.constant_(m.bias, 0)

# %% [markdown]
# #### Definizione del modello

# %%
# Definizione del modello ------------------------------------------------------------------------------------------------------------------------------------

model = AutoEncoder(encoder_size = [16,8],     # dimensioni layer dell'encoder
                    decoder_size = [8,16],     # dimensioni layer del decoder
                    latent_dim = 5,            # dimensione dello spazio latente
                    kernel_size = [4,4,4],     # dimensione del kernel per effettuare le operazioni di convoluzione
                    stride = [2,2,2],          # step della convoluzione
                    padding = [1,1,1],         # padding della convoluzione
                    dropout = False)           # dropout rimosso

# Applicazione della funzione di inizializzazione dei pesi ---------------------------------------------------------------------------------------------------

model.apply(weights_init_glorot)

# Definizione parametri per lo scheduler ---------------------------------------------------------------------------------------------------------------------

scheduler_params = {'mode': 'min',                             # loss minimizzata
                    'factor': 0.01,                            # fattore di riduzione del learning rate
                    'patience': 5,                             # n. epoche dopo le quali ridurre il learning rate
                    'verbose': True}

# Compilazione del modello -----------------------------------------------------------------------------------------------------------------------------------

model.compile(lr=0.003, Scheduler=True, scheduler_params=scheduler_params)
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv1d-1             [-1, 16, 2400]              80
#               ReLU-2             [-1, 16, 2400]               0
#             Conv1d-3              [-1, 8, 1200]             520
#               ReLU-4              [-1, 8, 1200]               0
#             Conv1d-5               [-1, 5, 600]             165
#    ConvTranspose1d-6              [-1, 8, 1200]             168
#               ReLU-7              [-1, 8, 1200]               0
#    ConvTranspose1d-8             [-1, 16, 2400]             528
#               ReLU-9             [-1, 16, 2400]               0
#   ConvTranspose1d-10              [-1, 1, 4800]              65
# ================================================================
# Total params: 1,526
# Trainable params: 1,526
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.02
# Forward/backward pass size (MB): 1.52
# Params size (MB): 0.01
# Estimated Total Size (MB): 1.55
# ----------------------------------------------------------------

# %% [markdown]
# #### Addestramento del modello

# %%
epochs_n = 100                                                # numero di epoche del training

t_loss, v_loss = model.fit(epochs = epochs_n)                 # attributo di classe che allena il modello, restituendo loss (train/val) per ogni epoca
torch.save(model.state_dict(), 'AutoEncoder_Model.pth')       # SALVATAGGIO PARAMETRI DELL'ALLENAMENTO
# Out:
# epoch:    1 	 time(s): 2.2311 	 train loss: 0.00545635 	 val loss: 0.00036833
# epoch:    2 	 time(s): 1.6692 	 train loss: 0.00029698 	 val loss: 0.00025397
# epoch:    3 	 time(s): 1.6604 	 train loss: 0.00022226 	 val loss: 0.00020719
# epoch:    4 	 time(s): 1.9791 	 train loss: 0.00018771 	 val loss: 0.00018466
# epoch:    5 	 time(s): 2.0907 	 train loss: 0.00017377 	 val loss: 0.00017470
# epoch:    6 	 time(s): 1.6567 	 train loss: 0.00016638 	 val loss: 0.00016572
# epoch:    7 	 time(s): 1.6588 	 train loss: 0.00015974 	 val loss: 0.00015919
# epoch:    8 	 time(s): 1.6944 	 train loss: 0.00015339 	 val loss: 0.00015047
# epoch:    9 	 time(s): 1.6634 	 train loss: 0.00014523 	 val loss: 0.00014001
# epoch:   10 	 time(s): 1.6417 	 train loss: 0.00013379 	 val loss: 0.00012509
# epoch:   11 	 time(s): 1.8642 	 train loss: 0.00011763 	 val loss: 0.00011220
# epoch:   12 	 time(s): 2.1446 	 train loss: 0.00010694 	 val loss: 0.00009469
# epoch:   13 	 time(s): 1.6538 	 train loss: 0.00009950 	 val loss: 0.00008782
# epoch:   14 	 time(s): 1.6057 	 train loss: 0.00009655 	 val loss: 0.00008171
# epoch:   15 	 time(s): 1.6506 	 train loss: 0.00009295 	 val loss: 0.00007386
# epoch:   16 	 time(s): 1.6519 	 train loss: 0.00008920 	 val loss: 0.00006605
# epoch:   17 	 time(s): 1.6578 	 train loss: 0.00008498 	 val loss: 0.00006052
# epoch:   18 	 time(s): 1.7491 	 train loss: 0.00008340 	 val loss: 0.00005844
# epoch:   19 	 time(s): 2.2133 	 train loss: 0.00008318 	 val loss: 0.00005723
# epoch:   20 	 time(s): 1.6969 	 train loss: 0.00008279 	 val loss: 0.00005647
# epoch:   21 	 time(s): 1.7091 	 train loss: 0.00008227 	 val loss: 0.00005611
# epoch:   22 	 time(s): 1.7000 	 train loss: 0.00008212 	 val loss: 0.00005587
# epoch:   23 	 time(s): 1.7576 	 train loss: 0.00008160 	 val loss: 0.00005537
# epoch:   24 	 time(s): 1.7505 	 train loss: 0.00008154 	 val loss: 0.00005538
# epoch:   25 	 time(s): 1.7855 	 train loss: 0.00008144 	 val loss: 0.00005523
# epoch:   26 	 time(s): 2.1972 	 train loss: 0.00008098 	 val loss: 0.00005512
# epoch:   27 	 time(s): 1.7019 	 train loss: 0.00008119 	 val loss: 0.00005542
# epoch:   28 	 time(s): 1.6514 	 train loss: 0.00008083 	 val loss: 0.00005478
# epoch:   29 	 time(s): 1.6425 	 train loss: 0.00008029 	 val loss: 0.00005509
# epoch:   30 	 time(s): 1.6419 	 train loss: 0.00008011 	 val loss: 0.00005811
# epoch:   31 	 time(s): 1.6320 	 train loss: 0.00007898 	 val loss: 0.00005332
# epoch:   32 	 time(s): 1.6508 	 train loss: 0.00007798 	 val loss: 0.00007127
# epoch:   33 	 time(s): 2.1500 	 train loss: 0.00007254 	 val loss: 0.00004878
# epoch:   34 	 time(s): 1.7148 	 train loss: 0.00006679 	 val loss: 0.00004559
# epoch:   35 	 time(s): 1.6258 	 train loss: 0.00006266 	 val loss: 0.00004416
# epoch:   36 	 time(s): 1.6222 	 train loss: 0.00006160 	 val loss: 0.00004269
# epoch:   37 	 time(s): 1.6336 	 train loss: 0.00005916 	 val loss: 0.00004120
# epoch:   38 	 time(s): 1.6523 	 train loss: 0.00006305 	 val loss: 0.00003999
# epoch:   39 	 time(s): 1.7091 	 train loss: 0.00005426 	 val loss: 0.00003817
# epoch:   40 	 time(s): 2.1118 	 train loss: 0.00005462 	 val loss: 0.00003686
# epoch:   41 	 time(s): 1.7858 	 train loss: 0.00005280 	 val loss: 0.00003639
# epoch:   42 	 time(s): 1.6372 	 train loss: 0.00005380 	 val loss: 0.00003589
# epoch:   43 	 time(s): 1.6549 	 train loss: 0.00005278 	 val loss: 0.00003557
# epoch:   44 	 time(s): 1.6823 	 train loss: 0.00005200 	 val loss: 0.00003510
# epoch:   45 	 time(s): 1.6506 	 train loss: 0.00005194 	 val loss: 0.00003488
# epoch:   46 	 time(s): 1.6678 	 train loss: 0.00005100 	 val loss: 0.00003523
# epoch:   47 	 time(s): 2.0494 	 train loss: 0.00005171 	 val loss: 0.00003609
# epoch:   48 	 time(s): 1.8167 	 train loss: 0.00005154 	 val loss: 0.00003443
# epoch:   49 	 time(s): 1.6620 	 train loss: 0.00005225 	 val loss: 0.00003434
# epoch:   50 	 time(s): 1.6659 	 train loss: 0.00005049 	 val loss: 0.00003562
# epoch:   51 	 time(s): 1.6708 	 train loss: 0.00005083 	 val loss: 0.00003585
# epoch:   52 	 time(s): 1.6573 	 train loss: 0.00005071 	 val loss: 0.00003404
# epoch:   53 	 time(s): 1.6713 	 train loss: 0.00005094 	 val loss: 0.00003457
# epoch:   54 	 time(s): 2.0625 	 train loss: 0.00005036 	 val loss: 0.00003702
# epoch:   55 	 time(s): 1.8255 	 train loss: 0.00005087 	 val loss: 0.00003378
# epoch:   56 	 time(s): 1.6890 	 train loss: 0.00005049 	 val loss: 0.00003346
# epoch:   57 	 time(s): 1.6775 	 train loss: 0.00005098 	 val loss: 0.00003622
# epoch:   58 	 time(s): 1.6748 	 train loss: 0.00004993 	 val loss: 0.00003380
# epoch:   59 	 time(s): 1.6809 	 train loss: 0.00005063 	 val loss: 0.00003411
# epoch:   60 	 time(s): 1.6819 	 train loss: 0.00005064 	 val loss: 0.00003519
# epoch:   61 	 time(s): 2.0595 	 train loss: 0.00004991 	 val loss: 0.00003309
# epoch:   62 	 time(s): 1.8137 	 train loss: 0.00005003 	 val loss: 0.00003324
# epoch:   63 	 time(s): 1.6634 	 train loss: 0.00005060 	 val loss: 0.00003480
# epoch:   64 	 time(s): 1.6790 	 train loss: 0.00005033 	 val loss: 0.00003562
# epoch:   65 	 time(s): 1.6595 	 train loss: 0.00005022 	 val loss: 0.00003468
# epoch:   66 	 time(s): 1.6600 	 train loss: 0.00004970 	 val loss: 0.00003341
# epoch:   67 	 time(s): 1.6644 	 train loss: 0.00005006 	 val loss: 0.00003286
# epoch:   68 	 time(s): 2.0723 	 train loss: 0.00005076 	 val loss: 0.00006111
# epoch:   69 	 time(s): 1.8290 	 train loss: 0.00005000 	 val loss: 0.00004739
# epoch:   70 	 time(s): 1.6271 	 train loss: 0.00005013 	 val loss: 0.00003584
# epoch:   71 	 time(s): 1.6674 	 train loss: 0.00004962 	 val loss: 0.00003297
# epoch:   72 	 time(s): 1.6822 	 train loss: 0.00004996 	 val loss: 0.00003270
# epoch:   73 	 time(s): 1.6994 	 train loss: 0.00004984 	 val loss: 0.00003268
# epoch:   74 	 time(s): 1.6604 	 train loss: 0.00004993 	 val loss: 0.00003608
# epoch:   75 	 time(s): 2.0722 	 train loss: 0.00004970 	 val loss: 0.00003305
# epoch:   76 	 time(s): 1.8814 	 train loss: 0.00005023 	 val loss: 0.00003617
# epoch:   77 	 time(s): 1.6739 	 train loss: 0.00004959 	 val loss: 0.00003260
# epoch:   78 	 time(s): 1.6694 	 train loss: 0.00004992 	 val loss: 0.00003554
# epoch:   79 	 time(s): 1.6780 	 train loss: 0.00004931 	 val loss: 0.00003306
# epoch:   80 	 time(s): 1.6606 	 train loss: 0.00004984 	 val loss: 0.00003294
# epoch:   81 	 time(s): 1.6336 	 train loss: 0.00005003 	 val loss: 0.00003540
# epoch:   82 	 time(s): 1.9770 	 train loss: 0.00004962 	 val loss: 0.00003323
# epoch:   83 	 time(s): 1.9565 	 train loss: 0.00004957 	 val loss: 0.00003258
# epoch:   84 	 time(s): 1.6527 	 train loss: 0.00004974 	 val loss: 0.00003271
# epoch:   85 	 time(s): 1.6450 	 train loss: 0.00004973 	 val loss: 0.00003463
# epoch:   86 	 time(s): 1.6318 	 train loss: 0.00004938 	 val loss: 0.00003245
# epoch:   87 	 time(s): 1.6876 	 train loss: 0.00004970 	 val loss: 0.00003476
# epoch:   88 	 time(s): 1.6730 	 train loss: 0.00004964 	 val loss: 0.00003408
# epoch:   89 	 time(s): 2.1342 	 train loss: 0.00005020 	 val loss: 0.00004269
# epoch:   90 	 time(s): 2.5025 	 train loss: 0.00004839 	 val loss: 0.00003267
# epoch:   91 	 time(s): 1.8757 	 train loss: 0.00005021 	 val loss: 0.00003515
# epoch:   92 	 time(s): 1.6823 	 train loss: 0.00004894 	 val loss: 0.00003268
# epoch:   93 	 time(s): 1.6616 	 train loss: 0.00004590 	 val loss: 0.00003199
# epoch:   94 	 time(s): 1.6419 	 train loss: 0.00004583 	 val loss: 0.00003197
# epoch:   95 	 time(s): 1.6493 	 train loss: 0.00004581 	 val loss: 0.00003195
# epoch:   96 	 time(s): 1.6682 	 train loss: 0.00004579 	 val loss: 0.00003194
# epoch:   97 	 time(s): 2.0588 	 train loss: 0.00004578 	 val loss: 0.00003193
# epoch:   98 	 time(s): 1.8116 	 train loss: 0.00004577 	 val loss: 0.00003192
# epoch:   99 	 time(s): 1.6540 	 train loss: 0.00004577 	 val loss: 0.00003191
# epoch:  100 	 time(s): 1.6803 	 train loss: 0.00004576 	 val loss: 0.00003190

# %%
# @title Plot della loss
fig, ax = plt.subplots(figsize=(13, 5))

ax.plot(np.arange(0, epochs_n, 1), t_loss, '-b', marker='d', label="Train Loss", markersize=4, linewidth=1)
ax.plot(np.arange(0, epochs_n, 1), v_loss, '-r', marker='d', label="Validation Loss", markersize=4, linewidth=1)

ax.set_xlabel('Epochs', fontsize=13)
ax.set_ylabel('Loss (log-scale)', fontsize=13)
ax.set_yscale('log')
ax.grid(True, which='both', linestyle='-', linewidth=0.5)
ax.annotate('Start of Training', xy=(0, t_loss[0]), xytext=(10, t_loss[0]), arrowprops=dict(facecolor='blue', shrink=0.05))

min_v_loss_epoch = np.argmin(v_loss)
min_v_loss_value = np.min(v_loss)
ax.plot(min_v_loss_epoch, min_v_loss_value, 's', color='green', label='Min Validation Loss')
ax.axhline(y=min_v_loss_value, color='r', linestyle='--', linewidth=0.75)
ax.axvline(x=min_v_loss_epoch, color='darkorange', linestyle='--', linewidth=0.75)

min_t_loss_epoch = np.argmin(t_loss)
min_t_loss_value = np.min(t_loss)
ax.axhline(y=min_t_loss_value, color='b', linestyle='--', linewidth=0.75)
ax.axvline(x=min_t_loss_epoch, color='darkorange', linestyle='--', linewidth=0.75)
ax.plot(min_t_loss_epoch, min_t_loss_value, 'o', color='darkorange', label='Min Training Loss')

ax.fill_between(np.arange(0, epochs_n, 1), t_loss[:epochs_n], v_loss[:epochs_n], color='gray', alpha=0.2)

plt.title('Plot Loss(epochs): smooth L1',fontsize=16)
ax.legend(loc='upper right', fontsize=12)
fig.tight_layout()
plt.show()

# %% [markdown]
#  ### **Ricostruzione tracce audio ed errori di ricostruzione per classe**

# %% [markdown]
# #### Funzione per ricostruzione tracce audio, plot e prova di ricostruzione

# %%
# Funzione per la ricostruzione delle tracce audio --------------------------------------------------------------------------------------------------------------------------------
def Reconstruction(data, len_audio, out_loss, criterion, save_rec, sr, string):
    output = []
    if torch.cuda.is_available(): model.cuda()                # garantisce compatibilità del modello con GPU se disponibile

    with torch.no_grad():                                     # evita che vengano cacolati automaticamente i gradienti
      for xb in data:
        if isinstance(xb, list): xb = torch.stack(xb)
        xb = xb.view(xb.shape[1], 1, len_audio)               # reshape di xb per adattarla al modello
        if torch.cuda.is_available(): xb = xb.cuda()          # spostamento del batch su GPU se disponibile
        _, x_rec = model(xb)                                  # attraverso il modello si ottiene l'output ricostruito di xb
        # '_' è la rappresentazione latente data dall'encoder (non necessaria ai fini della ricostruzione)
        # 'x_rec' è la ricostruzione degli audio originali a partire dalla rappresentazione latente.
        loss = criterion(x_rec, xb)                           # loss tra output ricostruito e input originale
        out_loss+=loss.item()
        output.append(x_rec.cpu())                            # spostamento dell'output sulla CPU

    output = torch.tensor(np.array(output))                   # conversione della lista di output in un tensore
    output = output.reshape(output.shape[0], len_audio)
    print(f'loss:  {out_loss}\nshape: {output.shape}')

    if save_rec:                                              # se save_rec=True, gli audio ricostruiti vengono salvati
      model.save(string, output, len_audio, sr)               # attributo di classe che salva gli audio nella cartella "Reconstructed_Audios_{stringa}"

    return output, out_loss                                   # restituisce l'output della ricostruzione e la loss totale

# Funzione per la creazione del grafico dei residui -------------------------------------------------------------------------------------------------------------------------------
def plot_residual(reconstructed, original, i, sr, zoom):
    if zoom:
      t = np.arange(zoom[0], zoom[1], 1) / sample_rate
      x = original[i][zoom[0]:zoom[1]]
      x_rec = reconstructed[i][zoom[0]:zoom[1]]
    else:
      t = np.arange(0, len(original[i]), 1) / sample_rate
      x = original[i]
      x_rec = reconstructed[i]
    plt.subplots(figsize=(12, 4))
    plt.plot(t, x_rec - x , '.', color='g', markersize=2, label='Residui tra traccia originale e ricostruita')
    plt.xlabel("Time (s)")
    plt.ylabel("Ampiezza del residuo: $y_{originale}-y_{ricostruito}$")
    plt.title(f'Grafico dei residui per la traccia n. {i+1}')
    plt.grid(True, which='both', linestyle='--', linewidth=0.5)
    plt.axhline(y=0, color='r', linestyle='--', linewidth=1, label='Retta di riferimento per y=0')
    max_residual_idx = np.argmax(np.abs(x_rec - x))
    plt.plot(t[max_residual_idx], x_rec[max_residual_idx] - x[max_residual_idx], 'o', color='darkorange', markersize=6, label='Residuo massimo')
    plt.legend(loc='best',fontsize=9)
    plt.show()

# %%
# Creazione Dataset e Dataloader a partire dal tensore audio_cut iniziale con batch=1,
# per valutare e ricostruire le tracce singolarmente e raggrupparle tutte insieme senza problemi di dimensione -----------------------------------------------

batch_eval = 1

dataset_audio = TensorDataset(audio_cut)
audio_dl_eval = DataLoader(dataset_audio, batch_size=batch_eval, shuffle=False, num_workers=0, drop_last=True)

# Ricostruzione ----------------------------------------------------------------------------------------------------------------------------------------------

model.eval()                                # modello in modalità valutazione
eval_loss = 0                               # inizializzazione loss di valutazione a zero
criterion = nn.SmoothL1Loss()               # loss per la valutazione, Smooth L1 Loss (Huber)

x_rec_plot , eval_loss = Reconstruction(audio_dl_eval, n_trim, eval_loss, criterion,
                                        save_rec=False, sr=False, string=False)
# Out:
# loss:  0.019126209885291345
# shape: torch.Size([445, 4800])

# %%
# Plot di una traccia audio casuale con la sua ricostruzione
rp = random.randint(0, x_rec_plot.shape[0]-1)

# %%
plot_audio(audio=audio_cut, audio_rec=x_rec_plot, i=rp, sr=sample_rate, reconstruction_plot=True, zoom=[0,n_trim])
plot_residual(reconstructed=x_rec_plot, original=audio_cut , i=rp, sr=sample_rate, zoom=False)

# %% [markdown]
# #### Salvataggio audio ricostruiti

# %%
# lunghezza con cui salvare le tracce audio ricostruite (in questo caso vengono ricostruiti per intero)
#------------------------------------------------------------------------------------------------------
n_trim_save = 64000
#------------------------------------------------------------------------------------------------------

# Conversione in tensore Torch e creazione DataLoader --------------------------------------------------------------------------------------------------------

audio_cut_save = torch.Tensor(np.array(cutter(audio_norm, n_trim_save, rand=False))).float()
dataset_audio_save = TensorDataset(audio_cut_save)
audio_dl_save = DataLoader(dataset_audio_save, batch_size=1, shuffle=False, num_workers=0, drop_last=True)

# Ricostruzione e salvataggio nella cartella "Reconstructed_Audios_Gruppo0" ----------------------------------------------------------------------------------

model.eval()
save_loss = 0

x_rec_save , save_loss = Reconstruction(audio_dl_save,n_trim_save, save_loss, criterion,
                                        save_rec=True, sr=sample_rate, string='Gruppo0')
# Out:
# loss:  0.020552409677161876
# shape: torch.Size([445, 64000])
# Audio ricostruiti salvati in "/content/ReconstructedAudios_Gruppo0"

# %%
# Plot di un audio ricostruita salvata casuale
rc = random.randint(0, x_rec_save.shape[0]-1)

# %%
plot_audio(audio=audio_cut_save, audio_rec=x_rec_save, i=rc, sr=sample_rate, reconstruction_plot=True, zoom=False)
plot_residual(reconstructed=x_rec_save, original=audio_cut_save , i=rc, sr=sample_rate, zoom=False)

# %% [markdown]
# #### Istogramma degli errori

# %%
model.eval()                                                               # impostazione del modello in modalità valutazione

# Calcolo errori di ricostruzione ----------------------------------------------------------------------------------------------------------------------------

true_labels = []
rec_errors = []

with torch.no_grad():
    for xb, yb in audio_dl:
        if isinstance(xb, list): xb = torch.stack(xb)
        xb = xb.view(xb.size(0), 1, -1)
        if torch.cuda.is_available():
                xb = xb.cuda()
                yb = yb.cuda()

        encoded, decoded = model(xb)                                       # applicazione del modello

        error = torch.mean((decoded - xb)**2, dim=[1, 2])                  # calcolo dell'errore medio tra l'output ricostruito e l'input originale
        rec_errors.extend(error.cpu().numpy())                             # porta i dati alla CPU e converte gli errori da tensori ad arrays
        true_labels.extend(yb.cpu().numpy())                               # converte le labels originali 'yb' da tensori ad arrays

true_labels = np.array(true_labels)
reconstruction_errors = np.array(rec_errors)

print(f'mean reconstruction error: {np.mean(reconstruction_errors):.4f}')  # errore medio di ricostruzione

class_rec_errors = {0: [], 1: [], 2: []}                                   # dizionario per gli errori di ogni classe
for true_label, error in zip(true_labels, reconstruction_errors):
    class_rec_errors[int(true_label.item())].append(error)                 # errore di ricostruzione per classe

# Plot degli errori di ricostruzione per ogni classe ---------------------------------------------------------------------------------------------------------

label_names = ['Bird',     # 0
               'Korean',   # 1
               'Arabic']   # 2

plt.figure(figsize=(10, 5))
alpha = [0.5,0.9,0.3]
for  label, errors in class_rec_errors.items():
    plt.hist(errors, bins=15, alpha=alpha[label],histtype = 'bar',label=f'Classe {label}: {label_names[label]}', density=False,stacked = True)
plt.xlabel('Errore di ricostruzione')
plt.ylabel('Frequenza')
plt.title('Istogramma degli errori di ricostruzione')
plt.grid()
plt.legend()
plt.show()
# Out:
# mean reconstruction error: 0.0001

# %%
# @title CELLA PROVVISORIA
color = ['blue','orange', 'lime']
plt.figure(figsize=(15, 3))
for  label, errors in class_rec_errors.items():
  plt.subplot(1,3,label+1)
  plt.xlabel('Errore di ricostruzione')
  plt.ticklabel_format(style='sci', axis='x', scilimits=(0,0))

  plt.grid()
  plt.hist(errors, bins=10, alpha=alpha[label],histtype = 'bar',label=f'Classe {label}: {label_names[label]}', density=False,stacked = False, color=color[label])
  plt.legend()

plt.suptitle('Istogrammi degli errori di ricostruzione distinti per classe')

plt.show()

# %% [markdown]
# #### Plot dello spazio latente tramite riduzione dimensionale con UMAP

# %%
# Installazione e importazione di UMAP
# !pip install umap-learn
import umap
# Out:
# Collecting umap-learn
#   Downloading umap_learn-0.5.6-py3-none-any.whl (85 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.7/85.7 kB 3.4 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from umap-learn) (1.25.2)
# Requirement already satisfied: scipy>=1.3.1 in /usr/local/lib/python3.10/dist-packages (from umap-learn) (1.11.4)
# Requirement already satisfied: scikit-learn>=0.22 in /usr/local/lib/python3.10/dist-packages (from umap-learn) (1.2.2)
# Requirement already satisfied: numba>=0.51.2 in /usr/local/lib/python3.10/dist-packages (from umap-learn) (0.58.1)
# Collecting pynndescent>=0.5 (from umap-learn)
#   Downloading pynndescent-0.5.13-py3-none-any.whl (56 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.9/56.9 kB 6.6 MB/s eta 0:00:00
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from umap-learn) (4.66.4)
# Requirement already satisfied: llvmlite<0.42,>=0.41.0dev0 in /usr/local/lib/python3.10/dist-packages (from numba>=0.51.2->umap-learn) (0.41.1)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.10/dist-packages (from pynndescent>=0.5->umap-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.22->umap-learn) (3.5.0)
# Installing collected packages: pynndescent, umap-learn
# Successfully installed pynndescent-0.5.13 umap-learn-0.5.6

# %%
audio_data = audio_cut                                    # dati audio senza label

# Conversione dati audio in tensore PyTorch, impostazione tipo a float32, aggiunta dimensione per il canale
audio_data = torch.tensor(audio_cut.clone().detach(), dtype=torch.float32).unsqueeze(1)

batch_size = batch_n                                      # dimensione del batch

# Creazione dataset e DataLoader
dataset = TensorDataset(audio_data)
dataloader = DataLoader(dataset, batch_size=batch_size, shuffle=False)

# Estrazione delle rappresentazioni latenti ------------------------------------------------------------------------------------------------------------------

latent_rep = []                                           # inizializza una lista per memorizzare le rappresentazioni latenti

with torch.no_grad():
    for xb in dataloader:
        xb = xb[0]
        if torch.cuda.is_available(): xb = xb.cuda()

        z, _ = model(xb)                                  # rappresentazione latente dal modello (data dall'output ddell'encoder)
        latent_rep.append(z)

latent_representations = torch.cat(latent_rep, dim=0)     # concatenazione rapp. latenti in un unico tensore
# Rimozione gradienti, spostamento su CPU, conversione in numpy e reshape
latent_representations = latent_representations.detach().cpu().numpy().reshape(len(dataset), -1)

#si applica UMAP per ridurre la dimensionalità a 2

manifold = umap.UMAP().fit(latent_representations, labels)  # applica UMAP
latent_representations_2d = manifold.transform(latent_representations)  # trasformazione rapp. latenti in 2D


# Scatter Plot dello spazio latente --------------------------------------------------------------------------------------------------------------------------

fig, ax = plt.subplots(figsize=(10, 6))
scatter = ax.scatter(latent_representations_2d[:, 0], latent_representations_2d[:, 1], c=labels, s=25, alpha=0.6, edgecolor='k', cmap='viridis')
legend = ax.legend(*scatter.legend_elements(), title="Labels")
ax.add_artist(legend)
ax.set_title("Spazio latente con labels", fontsize=16)
ax.set_xlabel("Umap (z[0])", fontsize=14)
ax.set_ylabel("Umap (z[1])", fontsize=14)
ax.tick_params(axis='both', which='major', labelsize=12)
ax.tick_params(axis='both', which='minor', labelsize=10)
ax.grid(True, which='both', linestyle='-', linewidth=0.7)
cbar = plt.colorbar(scatter, ax=ax)
cbar.set_label('Class Labels', fontsize=14)
cbar.ax.tick_params(labelsize=12)
fig.tight_layout()
plt.show()

# %% [markdown]
# # **Dataset di Test** ```gruppo_27``` (test)

# %% [markdown]
# ###**Estrazione e preparazione dei dati**

# %% [markdown]
# #### Estrazione da zip e normalizzazione file audio

# %%
# Funzione per lettura dati da file audio
def wav_file_reading(zip, folder):
  audio_data = []
  sample_rate = []
  test_paths = []
  with zipfile.ZipFile(zip, 'r') as zip_ref:
      zip_ref.extractall(folder)
      for file_name in zip_ref.namelist():
          if file_name.endswith('.wav'):
              file_path = os.path.join(folder, file_name)
              test_paths.append(file_path)
              sr, data = wavfile.read(file_path)
              sample_rate.append(sr)
              audio_data.append(data.astype(float))
  return test_paths, sample_rate, audio_data

# %%
# Ricerca percorso e creazione cartella dei file estratti
zip_file_path = '/content/gruppo_27.zip'
extract_dir = 'gruppo_27'
os.makedirs(extract_dir, exist_ok=True)

# LETTURA DATI DA FILE E NORMALIZZAZIONE
test_paths, sample_rates, audio_data_set = wav_file_reading(zip_file_path,extract_dir)

audio_norm_test = Normalize([np.array(data) for data in audio_data_set])

n_test_paths = len(test_paths)

for i in range(n_test_paths):
  print(f"{i+1:3d})  {test_paths[i]} / freq: {sample_rates[i]/1000}kHz / dim.: {len(audio_norm_test[i])} / data: {audio_norm_test[i]} ")
print(f'\nnumero di file contenuti nel dataset: {n_test_paths}')
# Out:
#   1)  gruppo_27/HEFUCQQNFI64jsq.wav / freq: 16.0kHz / dim.: 64000 / data: [0.43184239 0.42288749 0.40704658 ... 0.51876669 0.51263722 0.513332  ]
#   2)  gruppo_27/mORBrLImS2EkcuQ.wav / freq: 16.0kHz / dim.: 64000 / data: [0.5438713  0.54572403 0.54810172 ... 0.51503034 0.49614785 0.48731646]
#   3)  gruppo_27/QGF0rP4GlIn4Zow.wav / freq: 16.0kHz / dim.: 64000 / data: [0.46165604 0.45719403 0.45300993 ... 0.53990335 0.54535349 0.54655777]
#   4)  gruppo_27/VWe4k9bE6vMFsT1.wav / freq: 16.0kHz / dim.: 64000 / data: [0.54433448 0.54509102 0.54787012 ... 0.49976069 0.49985332 0.49974525]
#   5)  gruppo_27/b7LNU8mpy5xUJNF.wav / freq: 16.0kHz / dim.: 64000 / data: [0.49752196 0.49738301 0.49742933 ... 0.54124658 0.53568837 0.52937362]
#   6)  gruppo_27/5dPcjCXgm0aSlOL.wav / freq: 16.0kHz / dim.: 64000 / data: [0.4207414  0.43591842 0.4557736  ... 0.54702095 0.55906375 0.57728234]
#   7)  gruppo_27/ItYSFXJQNhfOKgt.wav / freq: 16.0kHz / dim.: 64000 / data: [0.50270963 0.49962173 0.4962868  ... 0.50002316 0.50006948 0.4999614 ]
#   8)  gruppo_27/6xpmYdFEmhajBTz.wav / freq: 16.0kHz / dim.: 64000 / data: [0.48396609 0.46489833 0.44579969 ... 0.61765659 0.62162454 0.62590128]
#   9)  gruppo_27/TQz4FRKEPqy35Gr.wav / freq: 16.0kHz / dim.: 64000 / data: [0.48575708 0.41641835 0.51834983 ... 0.50148991 0.49062051 0.48534021]
#  10)  gruppo_27/IgWtVZqIX4Sqv75.wav / freq: 16.0kHz / dim.: 64000 / data: [0.49696614 0.49803147 0.50081057 ... 0.49810866 0.49830938 0.49818586]
#  11)  gruppo_27/MjmnvEZWlTECM96.wav / freq: 16.0kHz / dim.: 64000 / data: [0.41445753 0.39508098 0.39244083 ... 0.50962652 0.51059921 0.51010514]
#  12)  gruppo_27/ICxrZghcNF0qCNv.wav / freq: 16.0kHz / dim.: 64000 / data: [0.5976779  0.59215057 0.57289753 ... 0.45926292 0.48036869 0.50124288]
#  13)  gruppo_27/g8asbRT01rjokkk.wav / freq: 16.0kHz / dim.: 64000 / data: [0.52227146 0.52820022 0.5222869  ... 0.48598867 0.48947799 0.48617394]
#  14)  gruppo_27/dbY1DkHGNLtpAYx.wav / freq: 16.0kHz / dim.: 64000 / data: [0.49999228 0.50002316 0.50008492 ... 0.50002316 0.50005404 0.50000772]
#  15)  gruppo_27/ZlduiYwk68PEBJ3.wav / freq: 16.0kHz / dim.: 64000 / data: [0.27517794 0.26630024 0.25976933 ... 0.49600889 0.49611697 0.49176303]
#  16)  gruppo_27/1vy1vVQ1gEm7ha6.wav / freq: 16.0kHz / dim.: 64000 / data: [0.48705399 0.50277139 0.52094366 ... 0.52732017 0.52413963 0.52344486]
#  17)  gruppo_27/t7jbAs96m8wwgdS.wav / freq: 16.0kHz / dim.: 64000 / data: [0.53680001 0.5089163  0.46363229 ... 0.49004925 0.51529281 0.53522518]
#  18)  gruppo_27/l68azDToU9i8xZR.wav / freq: 16.0kHz / dim.: 64000 / data: [0.54113851 0.45032346 0.45896957 ... 0.36187065 0.35095493 0.36183977]
#  19)  gruppo_27/PumTPoRCsrKzKmQ.wav / freq: 16.0kHz / dim.: 64000 / data: [0.48090908 0.48283901 0.48385802 ... 0.46579382 0.46233538 0.4567154 ]
#  20)  gruppo_27/GBF0viJfbktyEkC.wav / freq: 16.0kHz / dim.: 64000 / data: [0.3997437  0.37493245 0.34812951 ... 0.42940296 0.44087449 0.45036978]
#  21)  gruppo_27/PPt4QBGXTz5QaWv.wav / freq: 16.0kHz / dim.: 63998 / data: [0.50000772 0.50000772 0.50000772 ... 0.50000772 0.50000772 0.50000772]
#  22)  gruppo_27/WrmJ6BTIhZBmmLd.wav / freq: 16.0kHz / dim.: 64000 / data: [0.51839615 0.51079992 0.50502555 ... 0.49492813 0.49813954 0.49488181]
#  23)  gruppo_27/wE8Mp2K2xSLXGur.wav / freq: 16.0kHz / dim.: 64000 / data: [0.5023082  0.50037827 0.504655   ... 0.43885192 0.44644815 0.44928901]
#  24)  gruppo_27/Wxt4uDLLnKQAVtz.wav / freq: 16.0kHz / dim.: 64000 / data: [0.45120351 0.47863947 0.47777486 ... 0.4999614  0.50006948 0.4999614 ]
#  25)  gruppo_27/5do9bfnae6ogV16.wav / freq: 16.0kHz / dim.: 64000 / data: [0.6307184  0.61710077 0.59585604 ... 0.43764764 0.4473282  0.45538761]
#  26)  gruppo_27/ucuCL8aYc8xe6ii.wav / freq: 16.0kHz / dim.: 64000 / data: [0.46886628 0.4376322  0.44575337 ... 0.50669302 0.52679523 0.52379997]
#  27)  gruppo_27/r7S4Euz3acM7NyU.wav / freq: 16.0kHz / dim.: 64000 / data: [0.37105714 0.30718399 0.29881579 ... 0.63229323 0.75492906 0.78736741]
#  28)  gruppo_27/OddX3q1wJYRz2kN.wav / freq: 16.0kHz / dim.: 64000 / data: [0.5421112  0.53516343 0.53551854 ... 0.48566444 0.48186632 0.48134138]
#  29)  gruppo_27/cNHTwN9mGGrtojx.wav / freq: 16.0kHz / dim.: 64000 / data: [0.48903025 0.48899937 0.49089842 ... 0.4821288  0.483225   0.48348747]
#  30)  gruppo_27/Ln3gFU9thrfPNdf.wav / freq: 16.0kHz / dim.: 64000 / data: [0.56696877 0.55345922 0.57481202 ... 0.50000772 0.50000772 0.49999228]
#  31)  gruppo_27/bJsEI7hycKcQaGF.wav / freq: 16.0kHz / dim.: 64000 / data: [0.52415507 0.48804212 0.50158255 ... 0.49999228 0.50000772 0.50000772]
#  32)  gruppo_27/lXKEbkPMuoq7imF.wav / freq: 16.0kHz / dim.: 64000 / data: [0.64838117 0.66747981 0.67700598 ... 0.66985749 0.66967222 0.66775772]
#  33)  gruppo_27/DDBSzqX8SWvejI0.wav / freq: 16.0kHz / dim.: 64000 / data: [0.38607976 0.37548827 0.34524232 ... 0.48612762 0.50873103 0.54237367]
#  34)  gruppo_27/wRSm9emyo6kDqsM.wav / freq: 16.0kHz / dim.: 64000 / data: [0.49236517 0.48856706 0.49469654 ... 0.5394556  0.5360126  0.53780358]
#  35)  gruppo_27/e5NoAJRFcax5Gq6.wav / freq: 16.0kHz / dim.: 64000 / data: [0.50859207 0.50729516 0.50541154 ... 0.4957773  0.49279748 0.49024997]
#  36)  gruppo_27/7f36LUUsErPiC4M.wav / freq: 16.0kHz / dim.: 64000 / data: [0.49966805 0.49974525 0.49985332 ... 0.53576557 0.53267767 0.52735105]
#  37)  gruppo_27/zxU0fvmn4Lgte7x.wav / freq: 16.0kHz / dim.: 64000 / data: [0.48886041 0.4970279  0.49414072 ... 0.50346616 0.49739845 0.49786163]
#  38)  gruppo_27/nBBYwYc9lOJkBd3.wav / freq: 16.0kHz / dim.: 64000 / data: [0.46810974 0.46848029 0.46372493 ... 0.48368818 0.45750282 0.47209313]
#  39)  gruppo_27/JUrM5Y2rREmDBFX.wav / freq: 16.0kHz / dim.: 64000 / data: [0.57510537 0.56153407 0.54675848 ... 0.45467739 0.46077599 0.46713706]
#  40)  gruppo_27/NsTKmj43AljKMMc.wav / freq: 16.0kHz / dim.: 64000 / data: [0.47149099 0.47870123 0.48895305 ... 0.43730797 0.41953712 0.40754064]
#  41)  gruppo_27/p4SR0mS2aywDk5h.wav / freq: 16.0kHz / dim.: 64000 / data: [0.53880715 0.58333462 0.58676219 ... 0.62759962 0.6205129  0.6155877 ]
#  42)  gruppo_27/NKRTnS8Nq1nWLXh.wav / freq: 16.0kHz / dim.: 64000 / data: [0.49940558 0.49942102 0.49942102 ... 0.51652797 0.52222514 0.52191635]
#  43)  gruppo_27/jLql98A6XOKZiOi.wav / freq: 16.0kHz / dim.: 64000 / data: [0.54413377 0.50954932 0.46270592 ... 0.47223209 0.43789467 0.38634223]
#  44)  gruppo_27/XoJ0HjTssQkc8aH.wav / freq: 16.0kHz / dim.: 64000 / data: [0.40879124 0.3081258  0.3495345  ... 0.48249934 0.40065463 0.43911439]
#  45)  gruppo_27/ft6556KcVc5ALvR.wav / freq: 16.0kHz / dim.: 64000 / data: [0.50209205 0.50156711 0.4974602  ... 0.49539131 0.48097083 0.477358  ]
#  46)  gruppo_27/0yj1IWEFLX4Umlr.wav / freq: 16.0kHz / dim.: 64000 / data: [0.50274051 0.50815977 0.51109327 ... 0.52591518 0.4706727  0.49522148]
#  47)  gruppo_27/MxVYIejpPFG8Xsj.wav / freq: 16.0kHz / dim.: 64000 / data: [0.52870972 0.5426207  0.56358752 ... 0.44292794 0.43591842 0.42818324]
#  48)  gruppo_27/AfAEVk4Kb6HjaoW.wav / freq: 16.0kHz / dim.: 64000 / data: [0.56409702 0.43726165 0.49483549 ... 0.51154101 0.52732017 0.52293535]
#  49)  gruppo_27/ShumcvDGzh1eRHN.wav / freq: 16.0kHz / dim.: 64000 / data: [0.39554416 0.39469499 0.40178172 ... 0.4820516  0.48730102 0.50294122]
#  50)  gruppo_27/YF0YHPo1qkcz9bo.wav / freq: 16.0kHz / dim.: 64000 / data: [0.59242848 0.57898069 0.55373713 ... 0.46462042 0.46675107 0.46954562]
#  51)  gruppo_27/FAGOtd9RNO2QRT0.wav / freq: 16.0kHz / dim.: 64000 / data: [0.4971051  0.49898871 0.50186046 ... 0.55230126 0.50579753 0.46114654]
#  52)  gruppo_27/WBz1wKIk0idddf4.wav / freq: 16.0kHz / dim.: 64000 / data: [0.66158193 0.64144884 0.61354969 ... 0.58528    0.55464806 0.5227192 ]
#  53)  gruppo_27/ykkIaeggGAsUgXR.wav / freq: 16.0kHz / dim.: 64000 / data: [0.50042459 0.50040915 0.50037827 ... 0.50002316 0.49999228 0.49999228]
#  54)  gruppo_27/VAB54vPRUapoUgj.wav / freq: 16.0kHz / dim.: 64000 / data: [0.45009186 0.4470966  0.42796708 ... 0.46221186 0.44312866 0.4387284 ]
#  55)  gruppo_27/eQkTCHKsUtOrROn.wav / freq: 16.0kHz / dim.: 64000 / data: [0.5042999  0.50190678 0.50218469 ... 0.50433078 0.50601368 0.4951906 ]
#  56)  gruppo_27/NiahqXvEgLOGq9i.wav / freq: 16.0kHz / dim.: 64000 / data: [0.44445645 0.45605151 0.45623678 ... 0.46793991 0.47504207 0.47726536]
#  57)  gruppo_27/O7SeExqyJwflKsb.wav / freq: 16.0kHz / dim.: 64000 / data: [0.32463061 0.31768284 0.30426593 ... 0.54348531 0.54208032 0.545477  ]
#  58)  gruppo_27/gYMZZtnOPmjXrm4.wav / freq: 16.0kHz / dim.: 64000 / data: [0.49999228 0.50000772 0.50000772 ... 0.49999228 0.49999228 0.50000772]
#  59)  gruppo_27/nUoL019WAqiAuN7.wav / freq: 16.0kHz / dim.: 64000 / data: [0.50079513 0.49872624 0.49888064 ... 0.51817999 0.50660038 0.49874168]
#  60)  gruppo_27/M8wpuQJ4YUXR3gD.wav / freq: 16.0kHz / dim.: 64000 / data: [0.68185397 0.67328506 0.64950825 ... 0.49787707 0.49502077 0.49139249]
#  61)  gruppo_27/E68Q4nsZT2A7Q2q.wav / freq: 16.0kHz / dim.: 64000 / data: [0.49906591 0.50388303 0.5090707  ... 0.45074032 0.4556964  0.45798144]
#  62)  gruppo_27/Z9yZEDtYxQF6ePR.wav / freq: 16.0kHz / dim.: 64000 / data: [0.5269033  0.54652689 0.55276444 ... 0.50082601 0.49806234 0.49352314]
#  63)  gruppo_27/8ShRywAoR47wzIJ.wav / freq: 16.0kHz / dim.: 64000 / data: [0.5556825  0.54209576 0.52753632 ... 0.5286634  0.49826306 0.4621501 ]
#  64)  gruppo_27/apmRGKY3azX6KR3.wav / freq: 16.0kHz / dim.: 64000 / data: [0.41947537 0.40289336 0.39060353 ... 0.49823218 0.49806234 0.4982013 ]
#  65)  gruppo_27/R0zfx3tvYf8N2T8.wav / freq: 16.0kHz / dim.: 64000 / data: [0.4899103  0.48754806 0.48672976 ... 0.51433556 0.51896741 0.52844725]
#  66)  gruppo_27/7MTEntGg8lHgm2q.wav / freq: 16.0kHz / dim.: 64000 / data: [0.60400809 0.61271596 0.62298322 ... 0.49985332 0.49986876 0.49985332]
#  67)  gruppo_27/utXzu2FtOJqydBq.wav / freq: 16.0kHz / dim.: 64000 / data: [0.49917399 0.49932838 0.49954454 ... 0.43247541 0.43105498 0.41624851]
#  68)  gruppo_27/udZcsRLLJiot6ZN.wav / freq: 16.0kHz / dim.: 64000 / data: [0.50295666 0.50508731 0.50601368 ... 0.49980701 0.49823218 0.50050178]
#  69)  gruppo_27/G2f8LO85vXS1CQ4.wav / freq: 16.0kHz / dim.: 64000 / data: [0.50111936 0.50042459 0.49979157 ... 0.50484028 0.50340441 0.50278683]
#  70)  gruppo_27/HPSn9giuwGecezO.wav / freq: 16.0kHz / dim.: 64000 / data: [0.49880344 0.5023082  0.50403743 ... 0.53011472 0.53511711 0.53661474]
#
# numero di file contenuti nel dataset: 70

# %%
# Plot traccia casuale
rt = random.randint(0, n_test_paths-1)

# %%
plot_audio(audio=audio_norm_test, audio_rec=False, i=rt, sr=sample_rates[rt], reconstruction_plot=False, zoom=False)

# %% [markdown]
# #### Rimozione tracce fuori shape

# %%
lenght = 64000

# indici della lunghezza definita
index_keep = [index for index, array in enumerate(audio_norm_test) if len(array) == lenght]
print(f'tracce di dimensione =/= {lenght}: {[index for index, audio_norm_test[index] in enumerate(audio_norm_test) if len(audio_norm_test[index])!=lenght]}')

# si filtrano i file audio
audio_norm_test = np.array([audio_norm_test[index] for index in index_keep])
test_paths = np.array([test_paths[index] for index in index_keep])
print(f'numero di file di dim. {lenght}: {audio_norm_test.shape[0]}')
# Out:
# tracce di dimensione =/= 64000: [20]
# numero di file di dim. 64000: 69

# %% [markdown]
# ### **Applicazione del modello al dataset di test**

# %% [markdown]
# #### Taglio della lunghezza dei file audio

# %%
n_trim_test = 64000

audio_cut_test = torch.Tensor(np.array(cutter(audio_norm_test, n_trim_test, rand=False))) #conversione in tensore Torch

#print(audio_cut_test.shape) # shape check

# %% [markdown]
# #### Creazione DataLoader e ricostruzione dei dati

# %%
# Creazione TensorDataset e DataLoader a partire dal tensore audio -------------------------------------------------------------------------------------------

batch_test = 1
dataset_audio = TensorDataset(audio_cut_test)
audio_dl_test = DataLoader(dataset_audio, batch_size=batch_test, shuffle=False)

# Ricostruzione e salvataggio nella cartella "Reconstructed_Audios_Gruppo_27" --------------------------------------------------------------------------------

model.eval()
test_loss = 0
criterion = nn.SmoothL1Loss()

x_rec_test , test_loss = Reconstruction(audio_dl_test, n_trim_test, test_loss, criterion,
                                        save_rec=True, sr=16000, string="Gruppo27")
# Out:
# loss:  0.0038068399498980554
# shape: torch.Size([69, 64000])
# Audio ricostruiti salvati in "/content/ReconstructedAudios_Gruppo27"

# %%
# Plot traccia audio casuale con ricostruzione
if batch_test == 1: sb = random.randint(0,x_rec_test.shape[0]-1)
else: sb = random.randint(0, batch_test-1)

# %%
plot_audio(audio=audio_cut_test, audio_rec=x_rec_test, i=sb, sr=sample_rates[sb], reconstruction_plot=True, zoom=False)
plot_residual(reconstructed=x_rec_test, original=audio_cut_test , i=sb, sr=sample_rates[sb], zoom=False)

# %% [markdown]
# ### **Anomaly detection e classificazione del dataset di test**

# %%
from sklearn.cluster import KMeans, DBSCAN

# Estrazione delle rappresentazioni latenti
latent_representations = []
latent_vectors = []
errors = []

with torch.no_grad():
    for xb in audio_dl_test:
        if isinstance(xb, list): xb = torch.stack(xb)
        xb = xb.view(xb.shape[1], 1, n_trim_test)
        if torch.cuda.is_available(): xb = xb.cuda()
        encoded, decoded = model(xb)
        latent_representations.append(encoded)
        decoded = decoded.reshape(xb.shape)
        error = torch.mean((decoded - xb) ** 2, dim=[1, 2])
        errors.append(error.cpu().numpy())

errors = np.concatenate(errors)

latent_representations = torch.cat(latent_representations, dim=0)
latent_representations = latent_representations.detach().cpu().numpy().reshape(len(dataset_audio), -1)


if latent_representations.shape[1] > 2:
      manifold1 = umap.UMAP(n_neighbors=3, min_dist=0.01, n_components=2).fit(latent_representations)
      latent_representations_2d = manifold1.transform(latent_representations)
else: latent_representations_2d = latent_representations

# Clustering delle rappresentazioni latenti
kmeans = KMeans(n_clusters=3, init='k-means++', n_init=300, max_iter=1000, tol=1e-3, random_state=None, algorithm="elkan")
kmeans.fit(latent_representations_2d)
# Out:
# KMeans(algorithm='elkan', max_iter=1000, n_clusters=3, n_init=300, tol=0.001)

# %%
# ANOMALY DETECTION E CLASSIFICAZIONE
file_labels = []
labels_previsti = []
threshold = np.percentile(errors, 90)

print(f'Anomaly Detection : anomalie rispetto alle classi del training (soglia = {threshold:.6f}):')

c = 0
a = 0
anomaly_plots = []

with torch.no_grad():
    for path, xb in zip(test_paths, audio_dl_test):
        if isinstance(xb, list): xb = torch.stack(xb)
        xb = xb.view(xb.shape[1], 1, n_trim_test)
        if torch.cuda.is_available(): xb = xb.cuda()

        encoded, decoded = model(xb)
        decoded = decoded.reshape(xb.shape)
        error = torch.mean((decoded - xb) ** 2, dim=[1, 2])

        latent_point = latent_representations_2d[c, :]
        latent_point = latent_point.reshape(-1, 2)
        target = kmeans.predict(latent_point)

        if error > threshold:
            label = -1  # anomalia
            a += 1
            print(f'{a:3d})\t[{c + 1:2d}]\t{path}')
            # per grafico
            fig, ax = plt.subplots()
            ax.plot(xb.cpu().numpy().flatten())
            ax.set_title(f'[{c + 1:2d}] {path}', fontsize=5)
            anomaly_plots.append((fig, ax))
            plt.close(fig)

        else:
            label = target[0]  # assegnazione del cluster

        labels_previsti.append(label)
        file_labels.append([path, label])
        c += 1

if a == 0: print('\t nessuna anomalia rilevata\n')
else:
    num_plots = len(anomaly_plots)
    cols = 3
    rows = (num_plots + cols - 1) // cols
    fig, axs = plt.subplots(rows, cols, figsize=(11, rows * 3))
    fig.suptitle('Grafici delle anomalie', fontsize=14)
    axs = axs.flatten()
    for i, (plot_fig, plot_ax) in enumerate(anomaly_plots):
        axs[i].set_ylim(0, 1)
        axs[i].plot(plot_ax.lines[0].get_xdata()/sample_rate, plot_ax.lines[0].get_ydata(), linewidth = 0.1, color = 'b')
        axs[i].grid()
        axs[i].set_title(plot_ax.get_title())
        axs[i].ticklabel_format(style='sci', axis='x', scilimits=(0,0))
        axs[i].set_xlabel('t(s)')

    for i in range(len(anomaly_plots), len(axs)):
        fig.delaxes(axs[i])

    plt.tight_layout()
    plt.show()

print(f'Classificazione:\n {file_labels}\n\n')
# Out:
# Anomaly Detection : anomalie rispetto alle classi del training (soglia = 0.000368):
#   1)	[ 9]	gruppo_27/TQz4FRKEPqy35Gr.wav
#   2)	[18]	gruppo_27/l68azDToU9i8xZR.wav
#   3)	[26]	gruppo_27/r7S4Euz3acM7NyU.wav
#   4)	[31]	gruppo_27/lXKEbkPMuoq7imF.wav
#   5)	[36]	gruppo_27/zxU0fvmn4Lgte7x.wav
#   6)	[42]	gruppo_27/jLql98A6XOKZiOi.wav
#   7)	[47]	gruppo_27/AfAEVk4Kb6HjaoW.wav
# Classificazione:
#  [['gruppo_27/HEFUCQQNFI64jsq.wav', 0], ['gruppo_27/mORBrLImS2EkcuQ.wav', 1], ['gruppo_27/QGF0rP4GlIn4Zow.wav', 2], ['gruppo_27/VWe4k9bE6vMFsT1.wav', 1], ['gruppo_27/b7LNU8mpy5xUJNF.wav', 1], ['gruppo_27/5dPcjCXgm0aSlOL.wav', 0], ['gruppo_27/ItYSFXJQNhfOKgt.wav', 0], ['gruppo_27/6xpmYdFEmhajBTz.wav', 0], ['gruppo_27/TQz4FRKEPqy35Gr.wav', -1], ['gruppo_27/IgWtVZqIX4Sqv75.wav', 0], ['gruppo_27/MjmnvEZWlTECM96.wav', 2], ['gruppo_27/ICxrZghcNF0qCNv.wav', 1], ['gruppo_27/g8asbRT01rjokkk.wav', 2], ['gruppo_27/dbY1DkHGNLtpAYx.wav', 2], ['gruppo_27/ZlduiYwk68PEBJ3.wav', 1], ['gruppo_27/1vy1vVQ1gEm7ha6.wav', 2], ['gruppo_27/t7jbAs96m8wwgdS.wav', 1], ['gruppo_27/l68azDToU9i8xZR.wav', -1], ['gruppo_27/PumTPoRCsrKzKmQ.wav', 0], ['gruppo_27/GBF0viJfbktyEkC.wav', 1], ['gruppo_27/WrmJ6BTIhZBmmLd.wav', 0], ['gruppo_27/wE8Mp2K2xSLXGur.wav', 1], ['gruppo_27/Wxt4uDLLnKQAVtz.wav', 1], ['gruppo_27/5do9bfnae6ogV16.wav', 2], ['gruppo_27/ucuCL8aYc8xe6ii.wav', 0], ['gruppo_27/r7S4Euz3acM7NyU.wav', -1], ['gruppo_27/OddX3q1wJYRz2kN.wav', 2], ['gruppo_27/cNHTwN9mGGrtojx.wav', 2], ['gruppo_27/Ln3gFU9thrfPNdf.wav', 0], ['gruppo_27/bJsEI7hycKcQaGF.wav', 0], ['gruppo_27/lXKEbkPMuoq7imF.wav', -1], ['gruppo_27/DDBSzqX8SWvejI0.wav', 1], ['gruppo_27/wRSm9emyo6kDqsM.wav', 1], ['gruppo_27/e5NoAJRFcax5Gq6.wav', 2], ['gruppo_27/7f36LUUsErPiC4M.wav', 2], ['gruppo_27/zxU0fvmn4Lgte7x.wav', -1], ['gruppo_27/nBBYwYc9lOJkBd3.wav', 1], ['gruppo_27/JUrM5Y2rREmDBFX.wav', 2], ['gruppo_27/NsTKmj43AljKMMc.wav', 2], ['gruppo_27/p4SR0mS2aywDk5h.wav', 0], ['gruppo_27/NKRTnS8Nq1nWLXh.wav', 1], ['gruppo_27/jLql98A6XOKZiOi.wav', -1], ['gruppo_27/XoJ0HjTssQkc8aH.wav', 0], ['gruppo_27/ft6556KcVc5ALvR.wav', 1], ['gruppo_27/0yj1IWEFLX4Umlr.wav', 2], ['gruppo_27/MxVYIejpPFG8Xsj.wav', 1], ['gruppo_27/AfAEVk4Kb6HjaoW.wav', -1], ['gruppo_27/ShumcvDGzh1eRHN.wav', 2], ['gruppo_27/YF0YHPo1qkcz9bo.wav', 0], ['gruppo_27/FAGOtd9RNO2QRT0.wav', 2], ['gruppo_27/WBz1wKIk0idddf4.wav', 2], ['gruppo_27/ykkIaeggGAsUgXR.wav', 2], ['gruppo_27/VAB54vPRUapoUgj.wav', 0], ['gruppo_27/eQkTCHKsUtOrROn.wav', 1], ['gruppo_27/NiahqXvEgLOGq9i.wav', 2], ['gruppo_27/O7SeExqyJwflKsb.wav', 2], ['gruppo_27/gYMZZtnOPmjXrm4.wav', 1], ['gruppo_27/nUoL019WAqiAuN7.wav', 1], ['gruppo_27/M8wpuQJ4YUXR3gD.wav', 1], ['gruppo_27/E68Q4nsZT2A7Q2q.wav', 2], ['gruppo_27/Z9yZEDtYxQF6ePR.wav', 2], ['gruppo_27/8ShRywAoR47wzIJ.wav', 0], ['gruppo_27/apmRGKY3azX6KR3.wav', 1], ['gruppo_27/R0zfx3tvYf8N2T8.wav', 0], ['gruppo_27/7MTEntGg8lHgm2q.wav', 0], ['gruppo_27/utXzu2FtOJqydBq.wav', 0], ['gruppo_27/udZcsRLLJiot6ZN.wav', 0], ['gruppo_27/G2f8LO85vXS1CQ4.wav', 1], ['gruppo_27/HPSn9giuwGecezO.wav', 0]]

# %% [markdown]
# #### Salvataggio su file .csv

# %%
gruppo_27_df = pd.DataFrame(file_labels, columns=['filename', 'label'])
gruppo_27_df.to_csv('Gruppo_27_with_Labels.csv', index=True)
display(gruppo_27_df)
# Out:
#                          filename  label
# 0   gruppo_27/HEFUCQQNFI64jsq.wav      0
# 1   gruppo_27/mORBrLImS2EkcuQ.wav      1
# 2   gruppo_27/QGF0rP4GlIn4Zow.wav      2
# 3   gruppo_27/VWe4k9bE6vMFsT1.wav      1
# 4   gruppo_27/b7LNU8mpy5xUJNF.wav      1
# ..                            ...    ...
# 64  gruppo_27/7MTEntGg8lHgm2q.wav      0
# 65  gruppo_27/utXzu2FtOJqydBq.wav      0
# 66  gruppo_27/udZcsRLLJiot6ZN.wav      0
# 67  gruppo_27/G2f8LO85vXS1CQ4.wav      1
# 68  gruppo_27/HPSn9giuwGecezO.wav      0
#
# [69 rows x 2 columns]
